# %% [markdown]
# # Tutorial 1: Built-in demonstration scripts

# %% [markdown]
# MAVE-NN provides built-in demonstration scripts, or "demos", to help users quickly get started training and visualizing models. Demos are self-contained Python scripts that can be executed by calling `mavenn.run_demo`. To get a list of demo names, execute this function without passing any arguments:

# %%
# Import MAVE-NN
import mavenn

# Get list of demos
mavenn.run_demo()
# Out:
# To run a demo, execute
#
# 	>>> mavenn.run_demo(name)
#
# where 'name' is one of the following strings:
#
# 	1. "gb1_ge_evaluation"
# 	2. "mpsa_ge_training"
# 	3. "sortseq_mpa_visualization"
#
# Python code for each demo is located in
#
# 	/Users/jkinney/github/mavenn/mavenn/examples/demos/
# ['gb1_ge_evaluation', 'mpsa_ge_training', 'sortseq_mpa_visualization']

# %% [markdown]
# To see the Python code for any one of these demos, pass the keyword argument `print_code=True` to `mavenn.run_demo()`. Alternatively, navigate to the folder that is printed when executing `mavenn.run_demo()` on your machine and open the corresponding `*.py` file.

# %% [markdown]
# ## Evaluating a GE regression model

# %% [markdown]
# The `'gb1_ge_evaluation'` demo illustrates an additive G-P map and GE measurement process fit to data from a deep mutational scanning (DMS) experiment performed on protein GB1 by Olson et al., 2014.

# %%
mavenn.run_demo('gb1_ge_evaluation', print_code=False)
# Out:
# Running /Users/jkinney/github/mavenn/mavenn/examples/demos/gb1_ge_evaluation.py...
# Using mavenn at: /Users/jkinney/github/mavenn/mavenn
# Model loaded from these files:
# 	/Users/jkinney/github/mavenn/mavenn/examples/models/gb1_ge_additive.pickle
# 	/Users/jkinney/github/mavenn/mavenn/examples/models/gb1_ge_additive.h5
# Done!

# %% [markdown]
# ## Visualizing an MPA regression model

# %% [markdown]
# The `'sortseq_mpa_visualization'` demo illustrates an additive G-P map, along with an MPA measurement process, fit to data from a sort-seq MPRA performed by Kinney et al., 2010.

# %%
mavenn.run_demo('sortseq_mpa_visualization', print_code=False)
# Out:
# Running /Users/jkinney/github/mavenn/mavenn/examples/demos/sortseq_mpa_visualization.py...
# Using mavenn at: /Users/jkinney/github/mavenn/mavenn
# Model loaded from these files:
# 	/Users/jkinney/github/mavenn/mavenn/examples/models/sortseq_full-wt_mpa_additive.pickle
# 	/Users/jkinney/github/mavenn/mavenn/examples/models/sortseq_full-wt_mpa_additive.h5
# Done!

# %% [markdown]
# ## Training a GE regression model

# %% [markdown]
# The `'mpsa_ge_training'` demo uses GE regression to train a pairwise G-P map on data from a massively parallel splicing assay (MPSA) reported by Wong et al., 2018. This training process usually takes under a minute on a standard laptop.

# %%
mavenn.run_demo('mpsa_ge_training', print_code=False)
# Out:
# Running /Users/jkinney/github/mavenn/mavenn/examples/demos/mpsa_ge_training.py...
# Using mavenn at: /Users/jkinney/github/mavenn/mavenn
# N = 24,405 observations set as training data.
# Using 19.7% for validation.
# Data shuffled.
# Time to set data: 0.217 sec.
#
# LSMR            Least-squares solution of  Ax = b
#
# The matrix A has 19596 rows and 36 columns
# damp = 0.00000000000000e+00
#
# atol = 1.00e-06                 conlim = 1.00e+08
#
# btol = 1.00e-06             maxiter =       36
#
#
#    itn      x(1)       norm r    norm Ar  compatible   LS      norm A   cond A
#      0  0.00000e+00  1.392e+02  4.679e+03   1.0e+00  2.4e-01
#      1  5.99349e-03  1.268e+02  1.591e+03   9.1e-01  1.5e-01  8.1e+01  1.0e+00
#      2  8.79278e-03  1.261e+02  1.281e+03   9.1e-01  7.4e-02  1.4e+02  1.2e+00
#      3  1.00774e-02  1.252e+02  6.138e+01   9.0e-01  1.8e-03  2.8e+02  2.0e+00
#      4  1.03335e-02  1.251e+02  6.110e+00   9.0e-01  1.7e-04  2.9e+02  2.4e+00
#      5  1.03241e-02  1.251e+02  4.306e-01   9.0e-01  1.2e-05  3.0e+02  2.6e+00
#      6  1.03067e-02  1.251e+02  1.685e-02   9.0e-01  4.4e-07  3.0e+02  2.6e+00
#
# LSMR finished
# The least-squares solution is good enough, given atol
# istop =       2    normr = 1.3e+02
#     normA = 3.0e+02    normAr = 1.7e-02
# itn   =       6    condA = 2.6e+00
#     normx = 8.2e-01
#      6  1.03067e-02   1.251e+02  1.685e-02
#    9.0e-01  4.4e-07   3.0e+02  2.6e+00
# Linear regression time: 0.0049 sec
# Epoch 1/30
# 392/392 [==============================] - 1s 1ms/step - loss: 48.3302 - I_var: -0.0060 - val_loss: 41.2498 - val_I_var: 0.1708
# Epoch 2/30
# 392/392 [==============================] - 0s 734us/step - loss: 41.2481 - I_var: 0.1769 - val_loss: 40.5614 - val_I_var: 0.1873
# Epoch 3/30
# 392/392 [==============================] - 0s 737us/step - loss: 40.4902 - I_var: 0.1965 - val_loss: 39.9010 - val_I_var: 0.2073
# Epoch 4/30
# 392/392 [==============================] - 0s 753us/step - loss: 40.1422 - I_var: 0.2066 - val_loss: 39.8402 - val_I_var: 0.2078
# Epoch 5/30
# 392/392 [==============================] - 0s 758us/step - loss: 39.9162 - I_var: 0.2137 - val_loss: 39.5068 - val_I_var: 0.2187
# Epoch 6/30
# 392/392 [==============================] - 0s 723us/step - loss: 39.6304 - I_var: 0.2221 - val_loss: 39.1716 - val_I_var: 0.2283
# Epoch 7/30
# 392/392 [==============================] - 0s 728us/step - loss: 39.4674 - I_var: 0.2273 - val_loss: 38.9066 - val_I_var: 0.2365
# Epoch 8/30
# 392/392 [==============================] - 0s 762us/step - loss: 39.3254 - I_var: 0.2319 - val_loss: 39.0354 - val_I_var: 0.2343
# Epoch 9/30
# 392/392 [==============================] - 0s 732us/step - loss: 39.1365 - I_var: 0.2378 - val_loss: 38.7356 - val_I_var: 0.2425
# Epoch 10/30
# 392/392 [==============================] - 0s 742us/step - loss: 38.9267 - I_var: 0.2442 - val_loss: 38.4905 - val_I_var: 0.2504
# Epoch 11/30
# 392/392 [==============================] - 0s 739us/step - loss: 38.8142 - I_var: 0.2479 - val_loss: 38.5273 - val_I_var: 0.2498
# Epoch 12/30
# 392/392 [==============================] - 0s 733us/step - loss: 38.7231 - I_var: 0.2508 - val_loss: 38.0067 - val_I_var: 0.2664
# Epoch 13/30
# 392/392 [==============================] - 0s 755us/step - loss: 38.4575 - I_var: 0.2598 - val_loss: 38.0807 - val_I_var: 0.2646
# Epoch 14/30
# 392/392 [==============================] - 0s 781us/step - loss: 38.2300 - I_var: 0.2675 - val_loss: 37.6770 - val_I_var: 0.2783
# Epoch 15/30
# 392/392 [==============================] - 0s 739us/step - loss: 37.9412 - I_var: 0.2776 - val_loss: 36.7735 - val_I_var: 0.3063
# Epoch 16/30
# 392/392 [==============================] - 0s 775us/step - loss: 37.2929 - I_var: 0.2978 - val_loss: 36.0239 - val_I_var: 0.3277
# Epoch 17/30
# 392/392 [==============================] - 0s 765us/step - loss: 36.9838 - I_var: 0.3069 - val_loss: 35.7320 - val_I_var: 0.3369
# Epoch 18/30
# 392/392 [==============================] - 0s 744us/step - loss: 36.8941 - I_var: 0.3093 - val_loss: 36.2529 - val_I_var: 0.3207
# Epoch 19/30
# 392/392 [==============================] - 0s 740us/step - loss: 36.5409 - I_var: 0.3198 - val_loss: 35.9248 - val_I_var: 0.3316
# Epoch 20/30
# 392/392 [==============================] - 0s 766us/step - loss: 36.5440 - I_var: 0.3197 - val_loss: 35.7810 - val_I_var: 0.3363
# Epoch 21/30
# 392/392 [==============================] - 0s 742us/step - loss: 36.5809 - I_var: 0.3188 - val_loss: 36.0809 - val_I_var: 0.3258
# Epoch 22/30
# 392/392 [==============================] - 0s 742us/step - loss: 36.5522 - I_var: 0.3196 - val_loss: 36.1825 - val_I_var: 0.3227
# Epoch 23/30
# 392/392 [==============================] - 0s 727us/step - loss: 36.3992 - I_var: 0.3239 - val_loss: 35.7484 - val_I_var: 0.3360
# Epoch 24/30
# 392/392 [==============================] - 0s 745us/step - loss: 36.3858 - I_var: 0.3246 - val_loss: 35.5147 - val_I_var: 0.3449
# Epoch 25/30
# 392/392 [==============================] - 0s 747us/step - loss: 36.4268 - I_var: 0.3235 - val_loss: 35.6774 - val_I_var: 0.3384
# Epoch 26/30
# 392/392 [==============================] - 0s 724us/step - loss: 36.4557 - I_var: 0.3224 - val_loss: 35.9714 - val_I_var: 0.3303
# Epoch 27/30
# 392/392 [==============================] - 0s 1ms/step - loss: 36.4625 - I_var: 0.3225 - val_loss: 36.0573 - val_I_var: 0.3276
# Epoch 28/30
# 392/392 [==============================] - 0s 740us/step - loss: 36.3640 - I_var: 0.3252 - val_loss: 36.0627 - val_I_var: 0.3289
# Epoch 29/30
# 392/392 [==============================] - 0s 759us/step - loss: 36.3393 - I_var: 0.3259 - val_loss: 35.7693 - val_I_var: 0.3359
# Epoch 30/30
# 392/392 [==============================] - 0s 777us/step - loss: 36.4576 - I_var: 0.3225 - val_loss: 35.2842 - val_I_var: 0.3504
# Training time: 9.8 seconds
# I_var_test: 0.324 +- 0.021 bits
# I_pred_test: 0.357 +- 0.015 bits
# Done!

# %% [markdown]
# ## References
#
# 1. Kinney J, Murugan A, Callan C, Cox E. Using deep sequencing to characterize the biophysical mechanism of a transcriptional regulatory sequence. Proc Natl Acad Sci USA. 107, 9158-9163 (2010).
#
# 2. Olson CA, Wu NC, Sun R. A comprehensive biophysical description of pairwise epistasis throughout an entire protein domain. Curr Biol 24, 2643–2651 (2014).
#
# 3. Wong M, Kinney J, Krainer A. Quantitative activity profile and context dependence of all human 5' splice sites. Mol Cell 71, 1012-1026.e3 (2018).
