# %% [markdown]
# # Demos

# %%
import mavenn

# %% [markdown]
# Demos are self-contained Python scripts that can be executed by calling `mavenn.run_demo`. To get a list of demo names, execute this function without passing any arguments:

# %%
mavenn.run_demo()
# Out:
# To run a demo, execute
#
# 	>>> mavenn.run_demo(name)
#
# where 'name' is one of the following strings:
#
# 	1. "gb1_ge_evaluation"
# 	2. "mpsa_ge_training"
# 	3. "sortseq_mpa_visualization"
#
# Python code for each demo is located in
#
# 	/Users/jkinney/github/mavenn/mavenn/examples/demos/
# ['gb1_ge_evaluation', 'mpsa_ge_training', 'sortseq_mpa_visualization']

# %% [markdown]
# To see the Python code for any one of these demos, pass the keyword argument `print_code=True` to `mavenn.run_demo`. Alternatively, navigate to the folder that is printed when executing `mavenn.run_demo()` on your machine and open the corresonding `*.py` file.

# %% [markdown]
# ## Evaluating a GE regression model

# %% [markdown]
# The `'gb1_ge_evaluation'` demo illustrates an additive G-P map and GE measurement process fit to data from a deep mutational scanning (DMS) experiment performed on protein GB1 by Olson et al., 2014.

# %%
mavenn.run_demo('gb1_ge_evaluation')
# Out:
# Running /Users/jkinney/github/mavenn/mavenn/examples/demos/gb1_ge_evaluation.py...
# Using mavenn at: /Users/jkinney/github/mavenn/mavenn
# Model loaded from these files:
# 	/Users/jkinney/github/mavenn/mavenn/examples/models/gb1_ge_additive.pickle
# 	/Users/jkinney/github/mavenn/mavenn/examples/models/gb1_ge_additive.h5
# Done!

# %% [markdown]
# ## Visualizing an MPA regression model

# %% [markdown]
# The `'sortseq_mpa_visualization'` demo illustrates an additive G-P map, along with an MPA measurement process, fit to data from a sort-seq MPRA performed by Kinney et al., 2010.

# %%
mavenn.run_demo('sortseq_mpa_visualization', print_code=False)
# Out:
# Running /Users/jkinney/github/mavenn/mavenn/examples/demos/sortseq_mpa_visualization.py...
# Using mavenn at: /Users/jkinney/github/mavenn/mavenn
# Model loaded from these files:
# 	/Users/jkinney/github/mavenn/mavenn/examples/models/sortseq_full-wt_mpa_additive.pickle
# 	/Users/jkinney/github/mavenn/mavenn/examples/models/sortseq_full-wt_mpa_additive.h5
# Done!

# %% [markdown]
# ## Training a GE regression model

# %% [markdown]
# The `'mpsa_ge_training'` demo uses GE regression to train a pairwise G-P map on data from a massively parallel splicing assay (MPSA) reported by Wong et al., 2018. This training process takes ~30 seconds on a standard laptop.

# %%
mavenn.run_demo('mpsa_ge_training', print_code=False)
# Out:
# Running /Users/jkinney/github/mavenn/mavenn/examples/demos/mpsa_ge_training.py...
# Using mavenn at: /Users/jkinney/github/mavenn/mavenn
# N = 24,234 observations set as training data.
# Using 20.3% for validation.
# Data shuffled.
# Time to set data: 0.409 sec.
#
# LSMR            Least-squares solution of  Ax = b
#
# The matrix A has 19314 rows and 36 columns
# damp = 0.00000000000000e+00
#
# atol = 1.00e-06                 conlim = 1.00e+08
#
# btol = 1.00e-06             maxiter =       36
#
#
#    itn      x(1)       norm r    norm Ar  compatible   LS      norm A   cond A
#      0  0.00000e+00  1.403e+02  4.759e+03   1.0e+00  2.4e-01
#      1  1.45469e-02  1.276e+02  1.822e+03   9.1e-01  1.8e-01  8.1e+01  1.0e+00
#      2  1.33026e-02  1.270e+02  1.391e+03   9.1e-01  6.3e-02  1.7e+02  1.6e+00
#      3  1.73523e-02  1.258e+02  6.626e+01   9.0e-01  1.9e-03  2.8e+02  2.5e+00
#      4  1.68284e-02  1.257e+02  3.412e+00   9.0e-01  9.5e-05  2.9e+02  3.1e+00
#      5  1.68135e-02  1.257e+02  3.824e-01   9.0e-01  1.0e-05  2.9e+02  3.2e+00
#      6  1.68145e-02  1.257e+02  1.484e-02   9.0e-01  3.9e-07  3.0e+02  3.3e+00
#
# LSMR finished
# The least-squares solution is good enough, given atol
# istop =       2    normr = 1.3e+02
#     normA = 3.0e+02    normAr = 1.5e-02
# itn   =       6    condA = 3.3e+00
#     normx = 8.4e-01
#      6  1.68145e-02   1.257e+02  1.484e-02
#    9.0e-01  3.9e-07   3.0e+02  3.3e+00
# Linear regression time: 0.0265 sec
# Epoch 1/30
# 387/387 [==============================] - 1s 3ms/step - loss: 48.9963 - I_var: 0.0191 - val_loss: 42.7990 - val_I_var: 0.1824
# Epoch 2/30
# 387/387 [==============================] - 1s 2ms/step - loss: 42.4321 - I_var: 0.1986 - val_loss: 41.9418 - val_I_var: 0.2098
# Epoch 3/30
# 387/387 [==============================] - 1s 2ms/step - loss: 42.0874 - I_var: 0.2093 - val_loss: 41.8493 - val_I_var: 0.2139
# Epoch 4/30
# 387/387 [==============================] - 1s 2ms/step - loss: 41.8102 - I_var: 0.2166 - val_loss: 41.8367 - val_I_var: 0.2151
# Epoch 5/30
# 387/387 [==============================] - 1s 2ms/step - loss: 41.6455 - I_var: 0.2222 - val_loss: 41.4333 - val_I_var: 0.2272
# Epoch 6/30
# 387/387 [==============================] - 1s 2ms/step - loss: 41.5045 - I_var: 0.2282 - val_loss: 41.3714 - val_I_var: 0.2293
# Epoch 7/30
# 387/387 [==============================] - 1s 3ms/step - loss: 41.4226 - I_var: 0.2302 - val_loss: 41.1738 - val_I_var: 0.2354
# Epoch 8/30
# 387/387 [==============================] - 1s 3ms/step - loss: 41.2980 - I_var: 0.2358 - val_loss: 42.1105 - val_I_var: 0.2089
# Epoch 9/30
# 387/387 [==============================] - 1s 2ms/step - loss: 41.2650 - I_var: 0.2360 - val_loss: 41.3862 - val_I_var: 0.2305
# Epoch 10/30
# 387/387 [==============================] - 1s 2ms/step - loss: 41.1581 - I_var: 0.2408 - val_loss: 41.3906 - val_I_var: 0.2317
# Epoch 11/30
# 387/387 [==============================] - 1s 3ms/step - loss: 40.9992 - I_var: 0.2450 - val_loss: 41.4207 - val_I_var: 0.2315
# Epoch 12/30
# 387/387 [==============================] - 1s 2ms/step - loss: 41.0527 - I_var: 0.2466 - val_loss: 41.2024 - val_I_var: 0.2380
# Epoch 13/30
# 387/387 [==============================] - 1s 3ms/step - loss: 40.9638 - I_var: 0.2497 - val_loss: 41.1711 - val_I_var: 0.2391
# Epoch 14/30
# 387/387 [==============================] - 1s 3ms/step - loss: 40.9080 - I_var: 0.2506 - val_loss: 41.0389 - val_I_var: 0.2443
# Epoch 15/30
# 387/387 [==============================] - 1s 2ms/step - loss: 40.7928 - I_var: 0.2548 - val_loss: 41.4218 - val_I_var: 0.2340
# Epoch 16/30
# 387/387 [==============================] - 1s 3ms/step - loss: 40.7655 - I_var: 0.2569 - val_loss: 41.0967 - val_I_var: 0.2440
# Epoch 17/30
# 387/387 [==============================] - 1s 4ms/step - loss: 40.6874 - I_var: 0.2610 - val_loss: 41.2903 - val_I_var: 0.2403
# Epoch 18/30
# 387/387 [==============================] - 1s 3ms/step - loss: 40.5550 - I_var: 0.2640 - val_loss: 40.7489 - val_I_var: 0.2556
# Epoch 19/30
# 387/387 [==============================] - 1s 3ms/step - loss: 40.5902 - I_var: 0.2643 - val_loss: 40.9098 - val_I_var: 0.2524
# Epoch 20/30
# 387/387 [==============================] - 1s 2ms/step - loss: 40.4565 - I_var: 0.2696 - val_loss: 40.8511 - val_I_var: 0.2543
# Epoch 21/30
# 387/387 [==============================] - 1s 3ms/step - loss: 40.4685 - I_var: 0.2700 - val_loss: 41.3811 - val_I_var: 0.2401
# Epoch 22/30
# 387/387 [==============================] - 1s 2ms/step - loss: 40.2093 - I_var: 0.2791 - val_loss: 40.6952 - val_I_var: 0.2640
# Epoch 23/30
# 387/387 [==============================] - 1s 3ms/step - loss: 40.0812 - I_var: 0.2854 - val_loss: 40.7781 - val_I_var: 0.2640
# Epoch 24/30
# 387/387 [==============================] - 1s 3ms/step - loss: 40.0949 - I_var: 0.2882 - val_loss: 40.3105 - val_I_var: 0.2808
# Epoch 25/30
# 387/387 [==============================] - 1s 2ms/step - loss: 39.9933 - I_var: 0.2962 - val_loss: 40.1373 - val_I_var: 0.2878
# Epoch 26/30
# 387/387 [==============================] - 1s 2ms/step - loss: 39.2157 - I_var: 0.3183 - val_loss: 40.7210 - val_I_var: 0.2735
# Epoch 27/30
# 387/387 [==============================] - 1s 2ms/step - loss: 39.3019 - I_var: 0.3168 - val_loss: 39.3365 - val_I_var: 0.3132
# Epoch 28/30
# 387/387 [==============================] - 1s 2ms/step - loss: 38.9952 - I_var: 0.3269 - val_loss: 39.7875 - val_I_var: 0.3012
# Epoch 29/30
# 387/387 [==============================] - 1s 2ms/step - loss: 38.8354 - I_var: 0.3325 - val_loss: 39.8624 - val_I_var: 0.2975
# Epoch 30/30
# 387/387 [==============================] - 1s 3ms/step - loss: 38.8443 - I_var: 0.3297 - val_loss: 39.4737 - val_I_var: 0.3080
# Training time: 33.2 seconds
# I_var_test: 0.335 +- 0.024 bits
# I_pred_test: 0.371 +- 0.014 bits
# Done!

# %% [markdown]
# **References**
#
# 1. Olson C, Wu N, Sun R (2014). A comprehensive biophysical description of pairwise epistasis throughout an entire protein domain. [Curr Biol. 24(22):2643-2651.](https://dx.doi.org/10.1016/j.cub.2014.09.072)
#
# 1. Kinney J, Murugan A, Callan C, Cox E (2010). Using deep sequencing to characterize the biophysical mechanism of a transcriptional regulatory sequence. [Proc Natl Acad Sci USA. 107(20):9158-9163.](https://dx.doi.org/10.1073/pnas.1004290107)
#
# 1. Wong M, Kinney J, Krainer A (2018). Quantitative activity profile and context dependence of all human 5' splice sites. [Mol Cell. 71(6):1012-1026.e3.](https://dx.doi.org/10.1016/j.molcel.2018.07.033)
