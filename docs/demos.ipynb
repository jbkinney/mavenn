# %% [markdown]
# # Demos

# %%
import mavenn

# %% [markdown]
# Demos are self-contained Python scripts that can be executed by calling `mavenn.run_demo`. To get a list of demo names, execute this function without passing any arguments:

# %%
mavenn.run_demo()
# Out:
# To run a demo, execute
#
# 	>>> mavenn.run_demo(name)
#
# where 'name' is one of the following strings:
#
# 	1. "gb1_ge_evaluation"
# 	2. "mpsa_ge_training"
# 	3. "sortseq_mpa_visualization"
#
# Python code for each demo is located in
#
# 	/Users/jkinney/opt/anaconda3/lib/python3.7/site-packages/mavenn/examples/demos/
# ['gb1_ge_evaluation', 'mpsa_ge_training', 'sortseq_mpa_visualization']

# %% [markdown]
# To see the Python code for any one of these demos, pass the keyword argument `print_code=True` to `mavenn.run_demo`. Alternatively, navigate to the folder that is printed when executing `mavenn.run_demo()` on your machine and open the corresonding `*.py` file.

# %% [markdown]
# ## Evaluating a GE regression model

# %% [markdown]
# The `'gb1_ge_evaluation'` demo illustrates an additive G-P map and GE measurement process fit to data from a deep mutational scanning (DMS) experiment performed on protein GB1 by Olson et al., 2014.

# %%
mavenn.run_demo('gb1_ge_evaluation')
# Out:
# Running /Users/jkinney/opt/anaconda3/lib/python3.7/site-packages/mavenn/examples/demos/gb1_ge_evaluation.py...
# Using mavenn at: /Users/jkinney/opt/anaconda3/lib/python3.7/site-packages/mavenn
# Model loaded from these files:
# 	/Users/jkinney/opt/anaconda3/lib/python3.7/site-packages/mavenn/examples/models/gb1_ge_additive.pickle
# 	/Users/jkinney/opt/anaconda3/lib/python3.7/site-packages/mavenn/examples/models/gb1_ge_additive.h5
# Done!

# %% [markdown]
# ## Visualizing an MPA regression model

# %% [markdown]
# The `'sortseq_mpa_visualization'` demo illustrates an additive G-P map, along with an MPA measurement process, fit to data from a sort-seq MPRA performed by Kinney et al., 2010.

# %%
mavenn.run_demo('sortseq_mpa_visualization', print_code=False)
# Out:
# Running /Users/jkinney/opt/anaconda3/lib/python3.7/site-packages/mavenn/examples/demos/sortseq_mpa_visualization.py...
# Using mavenn at: /Users/jkinney/opt/anaconda3/lib/python3.7/site-packages/mavenn
# Model loaded from these files:
# 	/Users/jkinney/opt/anaconda3/lib/python3.7/site-packages/mavenn/examples/models/sortseq_mpa_additive.pickle
# 	/Users/jkinney/opt/anaconda3/lib/python3.7/site-packages/mavenn/examples/models/sortseq_mpa_additive.h5
# Done!

# %% [markdown]
# ## Training a GE regression model

# %% [markdown]
# The `'mpsa_ge_training'` demo uses GE regression to train a pairwise G-P map on data from a massively parallel splicing assay (MPSA) reported by Wong et al., 2018. This training process takes ~30 seconds on a standard laptop.

# %%
mavenn.run_demo('mpsa_ge_training', print_code=False)
# Out:
# Running /Users/jkinney/opt/anaconda3/lib/python3.7/site-packages/mavenn/examples/demos/mpsa_ge_training.py...
# Using mavenn at: /Users/jkinney/opt/anaconda3/lib/python3.7/site-packages/mavenn
# N = 24,234 observations set as training data.
# Using 20.0% for validation.
# Data shuffled.
# Time to set data: 0.38 sec.
#
# LSMR            Least-squares solution of  Ax = b
#
# The matrix A has    19395 rows  and       36 cols
# damp = 0.00000000000000e+00
#
# atol = 1.00e-06                 conlim = 1.00e+08
#
# btol = 1.00e-06             maxiter =       36
#
#
#    itn      x(1)       norm r    norm Ar  compatible   LS      norm A   cond A
#      0  0.00000e+00  1.393e+02  4.730e+03   1.0e+00  2.4e-01
#      1  1.03770e-03  1.265e+02  1.588e+03   9.1e-01  1.6e-01  8.1e+01  1.0e+00
#      2  3.38918e-03  1.253e+02  1.102e+03   9.0e-01  7.0e-02  1.2e+02  1.0e+00
#      3  2.17146e-03  1.248e+02  6.216e+01   9.0e-01  1.8e-03  2.8e+02  2.0e+00
#      4  1.27263e-03  1.248e+02  3.218e+00   9.0e-01  9.0e-05  2.9e+02  2.4e+00
#      5  1.38556e-03  1.248e+02  3.699e-01   9.0e-01  1.0e-05  2.9e+02  2.5e+00
#      6  1.37829e-03  1.248e+02  1.463e-02   9.0e-01  3.9e-07  3.0e+02  2.6e+00
#
# LSMR finished
# The least-squares solution is good enough, given atol
# istop =       2    normr = 1.2e+02
#     normA = 3.0e+02    normAr = 1.5e-02
# itn   =       6    condA = 2.6e+00
#     normx = 8.4e-01
#      6  1.37829e-03   1.248e+02  1.463e-02
#    9.0e-01  3.9e-07   3.0e+02  2.6e+00
# Linear regression time: 0.0101 sec
# Epoch 1/30
# 388/388 [==============================] - 2s 4ms/step - loss: 49.5116 - I_like: -0.0350 - val_loss: 45.3545 - val_I_like: 0.0700
# Epoch 2/30
# 388/388 [==============================] - 1s 2ms/step - loss: 42.6718 - I_like: 0.1504 - val_loss: 42.1712 - val_I_like: 0.1666
# Epoch 3/30
# 388/388 [==============================] - 1s 2ms/step - loss: 42.0636 - I_like: 0.1705 - val_loss: 42.1964 - val_I_like: 0.1664
# Epoch 4/30
# 388/388 [==============================] - 1s 3ms/step - loss: 41.8443 - I_like: 0.1777 - val_loss: 41.7982 - val_I_like: 0.1787
# Epoch 5/30
# 388/388 [==============================] - 1s 2ms/step - loss: 41.6747 - I_like: 0.1831 - val_loss: 42.1930 - val_I_like: 0.1691
# Epoch 6/30
# 388/388 [==============================] - 1s 2ms/step - loss: 41.5999 - I_like: 0.1865 - val_loss: 41.4690 - val_I_like: 0.1894
# Epoch 7/30
# 388/388 [==============================] - 1s 3ms/step - loss: 41.4773 - I_like: 0.1902 - val_loss: 41.6573 - val_I_like: 0.1854
# Epoch 8/30
# 388/388 [==============================] - 1s 3ms/step - loss: 41.3619 - I_like: 0.1940 - val_loss: 41.2186 - val_I_like: 0.1990
# Epoch 9/30
# 388/388 [==============================] - 1s 3ms/step - loss: 41.3009 - I_like: 0.1962 - val_loss: 41.3359 - val_I_like: 0.1945
# Epoch 10/30
# 388/388 [==============================] - 1s 2ms/step - loss: 41.2001 - I_like: 0.1997 - val_loss: 41.1885 - val_I_like: 0.1997
# Epoch 11/30
# 388/388 [==============================] - 1s 2ms/step - loss: 41.1558 - I_like: 0.2012 - val_loss: 41.6839 - val_I_like: 0.1847
# Epoch 12/30
# 388/388 [==============================] - 1s 2ms/step - loss: 41.1140 - I_like: 0.2030 - val_loss: 40.9790 - val_I_like: 0.2061
# Epoch 13/30
# 388/388 [==============================] - 1s 2ms/step - loss: 41.0201 - I_like: 0.2062 - val_loss: 40.8478 - val_I_like: 0.2110
# Epoch 14/30
# 388/388 [==============================] - 1s 2ms/step - loss: 41.0392 - I_like: 0.2064 - val_loss: 40.9252 - val_I_like: 0.2100
# Epoch 15/30
# 388/388 [==============================] - 1s 2ms/step - loss: 40.9290 - I_like: 0.2105 - val_loss: 41.2641 - val_I_like: 0.1997
# Epoch 16/30
# 388/388 [==============================] - 1s 2ms/step - loss: 40.8823 - I_like: 0.2127 - val_loss: 41.0136 - val_I_like: 0.2086
# Epoch 17/30
# 388/388 [==============================] - 1s 2ms/step - loss: 40.7957 - I_like: 0.2156 - val_loss: 40.8052 - val_I_like: 0.2156
# Epoch 18/30
# 388/388 [==============================] - 1s 2ms/step - loss: 40.7685 - I_like: 0.2171 - val_loss: 40.8717 - val_I_like: 0.2145
# Epoch 19/30
# 388/388 [==============================] - 1s 2ms/step - loss: 40.7264 - I_like: 0.2189 - val_loss: 40.6277 - val_I_like: 0.2219
# Epoch 20/30
# 388/388 [==============================] - 1s 2ms/step - loss: 40.6998 - I_like: 0.2209 - val_loss: 40.6978 - val_I_like: 0.2199
# Epoch 21/30
# 388/388 [==============================] - 1s 2ms/step - loss: 40.6273 - I_like: 0.2235 - val_loss: 40.5593 - val_I_like: 0.2255
# Epoch 22/30
# 388/388 [==============================] - 1s 3ms/step - loss: 40.5087 - I_like: 0.2280 - val_loss: 40.3981 - val_I_like: 0.2311
# Epoch 23/30
# 388/388 [==============================] - 1s 2ms/step - loss: 40.5556 - I_like: 0.2279 - val_loss: 40.4133 - val_I_like: 0.2320
# Epoch 24/30
# 388/388 [==============================] - 1s 2ms/step - loss: 40.4315 - I_like: 0.2332 - val_loss: 40.1405 - val_I_like: 0.2427
# Epoch 25/30
# 388/388 [==============================] - 1s 2ms/step - loss: 40.1748 - I_like: 0.2439 - val_loss: 39.7261 - val_I_like: 0.2574
# Epoch 26/30
# 388/388 [==============================] - 1s 3ms/step - loss: 39.9446 - I_like: 0.2540 - val_loss: 39.6657 - val_I_like: 0.2631
# Epoch 27/30
# 388/388 [==============================] - 1s 3ms/step - loss: 39.8705 - I_like: 0.2586 - val_loss: 40.0381 - val_I_like: 0.2542
# Epoch 28/30
# 388/388 [==============================] - 1s 2ms/step - loss: 39.6851 - I_like: 0.2657 - val_loss: 39.1912 - val_I_like: 0.2803
# Epoch 29/30
# 388/388 [==============================] - 1s 2ms/step - loss: 39.5515 - I_like: 0.2709 - val_loss: 40.7588 - val_I_like: 0.2353
# Epoch 30/30
# 388/388 [==============================] - 1s 2ms/step - loss: 39.1444 - I_like: 0.2838 - val_loss: 39.4049 - val_I_like: 0.2744
# Training time: 32.0 seconds
# I_like_test: 0.311 +- 0.022 bits
# I_pred_test: 0.374 +- 0.010 bits
# Done!

# %% [markdown]
# **References**
#
# 1. Olson C, Wu N, Sun R (2014). A comprehensive biophysical description of pairwise epistasis throughout an entire protein domain. [Curr Biol. 24(22):2643-2651.](https://dx.doi.org/10.1016/j.cub.2014.09.072)
#
# 1. Kinney J, Murugan A, Callan C, Cox E (2010). Using deep sequencing to characterize the biophysical mechanism of a transcriptional regulatory sequence. [Proc Natl Acad Sci USA. 107(20):9158-9163.](https://dx.doi.org/10.1073/pnas.1004290107)
#
# 1. Wong M, Kinney J, Krainer A (2018). Quantitative activity profile and context dependence of all human 5' splice sites. [Mol Cell. 71(6):1012-1026.e3.](https://dx.doi.org/10.1016/j.molcel.2018.07.033)
