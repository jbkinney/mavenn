# %%
import mavenn

# %%
model = mavenn.load_example_model('sortseq_mpa_additive')
# Out:
# Model loaded from these files:
# 	/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mavenn/examples/models/sortseq_mpa_additive.pickle
# 	/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mavenn/examples/models/sortseq_mpa_additive.h5

# %%
#model.get_theta()['logomaker_df'].fillna(0).to_csv('data/sortseq_mpa_additive_theta.csv')

# %%
model.get_theta()
# Out:
# {'L': 39,
#  'C': 4,
#  'alphabet': array(['A', 'C', 'G', 'T'], dtype='<U1'),
#  'theta_0': -1.1306967676897681,
#  'theta_lc': array([[-3.45301517e-02, -4.19852324e-02, -6.27018886e-03,
#           1.64500792e-01],
#         [ 5.41233354e-02, -1.74570262e-01,  1.16795980e-02,
#          -1.04753419e-01],
#         [-4.61191496e-01,  8.66803918e-02,  7.81927052e-02,
#          -8.77012810e-01],
#         [-1.34519183e+00, -1.47753649e+00, -1.23691087e+00,
#           1.45072587e-01],
#         [-5.74199605e-01, -1.58083864e+00, -5.23247216e-01,
#           8.69542177e-02],
#         [-1.56109773e+00, -1.19343077e+00,  1.05636336e+00,
#           6.10645851e-02],
#         [ 1.26323080e-01, -1.12081131e+00, -4.60630359e-01,
#          -9.59665739e-01],
#         [-1.21282673e+00,  1.68782534e-01, -1.52973532e+00,
#          -5.65683683e-01],
#         [ 7.30132091e-02, -7.58202769e-01, -4.64041717e-01,
#          -2.90448464e-01],
# ...
