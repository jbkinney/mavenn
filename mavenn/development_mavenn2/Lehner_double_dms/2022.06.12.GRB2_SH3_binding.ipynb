# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '/Users/tareen/Desktop/Research_Projects/2022_mavenn2_github/mavenn')

import mavenn
import logomaker
import seaborn as sns
import re

# %matplotlib inline

# %%
binding_df_full = pd.read_csv('data/GRB2-SH3.binding.csv')
binding_df = binding_df_full[['aa_seq','count_e1_s0','count_e1_s1']].dropna().reset_index(drop=True).copy()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3457: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
abundance_df = pd.read_csv('data/GRB2-SH3.abundance.csv')
abundance_df = abundance_df[['aa_seq','count_e1_s0','count_e1_s1']].dropna().reset_index(drop=True).copy()

# %%
data_df = binding_df.copy()
y_cols = data_df.columns[1:]

# %%
X = data_df['aa_seq']
y = data_df[y_cols]

# %%
# set positional argumnets for gpmap function
L = len(data_df['aa_seq'][0])
alphabet=['A', 'C', 'D', 'E', 'F',
          'G', 'H', 'I', 'K', 'L',
          'M', 'N', 'P', 'Q', 'R',
          'S', 'T', 'V', 'W', 'Y', '*']


Y = len(y_cols)
print(f'L={L}, Y={Y}')
# Out:
# L=57, Y=2

# %%
gpmap_binding_DM = mavenn.gpmap.AdditiveGPMapLayer(L, alphabet)
gpmap_binding_EE = mavenn.gpmap.AdditiveGPMapLayer(L, alphabet)

gpmap_abundance = mavenn.gpmap.AdditiveGPMapLayer(L, alphabet)

# # instantiate gpmap object
# gpmap = mavenn.gpmap.Multi_AdditiveGPMapLayer(L=L, 
#                                               alphabet=alphabet,
#                                               number_latent_nodes=2)
# Out:
# 2022-06-12 21:25:37.255876: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
from sklearn.model_selection import train_test_split

# split data into training and testing sets
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %%
def model_local(gpmap, 
                mp,
                x_train,
                y_train):
    
    model = mavenn.Model2(gpmap=gpmap,
                          mp_list=[mp])
    
    # Set training data
    model.set_data(x=x_train.values,
                   y_list=[y_train.values],
                   shuffle=True)
    
    return model

# %%
mp_DM = mavenn.measurement_process_layers.DiscreteMonotonicMP(info_for_layers_dict={'H_y_norm':0},
                                                               Y=Y,
                                                               K=50,
                                                               eta=1e-5,)


mp_EE = mavenn.measurement_process_layers.ExponentialEnrichmentMP(Y=Y,
                                                                  t_y=[0,1],
                                                                  eta=1e-5,
                                                                  info_for_layers_dict={'H_y_norm':0})

# %%
model_binding_DM = model_local(gpmap_binding_DM,mp_DM, x_train, y_train)
model_binding_EE = model_local(gpmap_binding_EE,mp_EE, x_train, y_train)
# Out:
# N = 38,449 observations set as training data.
# Using 20.2% for validation.
# Data shuffled.
# Time to set data: 1.22 sec.
# N = 38,449 observations set as training data.
# Using 20.0% for validation.
# Data shuffled.
# Time to set data: 1.2 sec.

# %%
# # Set training data
# model.set_data(x=x_train.values,
#                y_list=[y_train.values],
#                shuffle=True)

# %%
# from tensorflow.keras.utils import plot_model
# plot_model(model.model,show_shapes=True,show_dtype=False,dpi=300,to_file='lehner.png')

# %%
# Fit model to data
model_binding_DM.fit(learning_rate=.0005,
                     epochs=300,
                     batch_size=300,
                     try_tqdm = False,
                     early_stopping=False,
                     verbose=False,
                     early_stopping_patience=10,
                     linear_initialization=False)

model_binding_EE.fit(learning_rate=.0005,
                     epochs=300,
                     batch_size=300,
                     try_tqdm = False,
                     early_stopping=False,
                     verbose=False,
                     early_stopping_patience=10,
                     linear_initialization=False)
# Out:
# Training time: 128.0 seconds
# Training time: 106.2 seconds

# %%
# Show training history
print('On test data:')
# x_test = test_df['x'].values
# y_test = test_df[y_cols].values


I_var_hist = model_binding_DM.history['I_var']
val_I_var_hist = model_binding_DM.history['val_I_var']

fig, ax = plt.subplots(figsize=[4,4])

ax.plot(I_var_hist, label='I_var_train-DM')
ax.plot(val_I_var_hist, label='I_var_val-DM')
#ax.set_xscale('log')
ax.set_title('training history - binding')

I_var_hist = model_binding_EE.history['I_var']
val_I_var_hist = model_binding_EE.history['val_I_var']

ax.plot(I_var_hist, label='I_var_train-EE')
ax.plot(val_I_var_hist, label='I_var_val-EE')

ax.legend()
ax.set_xlabel('epochs')
ax.set_ylabel('bits')

fig.tight_layout()
fig.savefig('plots/GRB2_SH3/training_history_binding.png',dpi=200,bbox_inches='tight')
# Out:
# On test data:

# %%
phi_DM = gpmap_binding_DM.x_to_phi(x_test)
phi_EE = gpmap_binding_EE.x_to_phi(x_test)

# %%
theta_lc_DM = gpmap_binding_DM.get_theta(model_binding_DM,gauge='consensus')['theta_lc']
theta_lc_EE = gpmap_binding_EE.get_theta(model_binding_EE,gauge='consensus')['theta_lc']
# theta_lc_consensus_df = pd.DataFrame(theta_lc,columns=alphabet)
# theta_raw_df = pd.DataFrame(theta,columns=alphabet)

# %%
# # Create fig and ax objects
fig, axs = plt.subplots(2,1, figsize=[12,8])

ax = axs[0]
# Draw heatmap
ax, cb = mavenn.heatmap(ax=ax,
                        values=theta_lc_DM,
                        alphabet=alphabet,
                        seq=model_binding_DM.x_stats['consensus_seq'],
                        seq_kwargs={'c':'gray', 's':20,'marker':'o'},
                        cmap='RdBu',
                        cbar=True,
                        #clim = [-5,1],
                        cmap_size='2%',
                        cmap_pad=.3,
                        ccenter=0)

# Style colorbar
cb.set_label('Additive effect - WT gauge ($\\theta$)',
             labelpad=10, ha='center', va='center', rotation=-90)
cb.outline.set_visible(False)
cb.ax.tick_params(direction='in', size=20, color='white')
ax.set_title('Discrete monotonic - binding')

ax = axs[1]
# Draw heatmap
ax, cb = mavenn.heatmap(ax=ax,
                        values=theta_lc_EE,
                        alphabet=alphabet,
                        seq=model_binding_EE.x_stats['consensus_seq'],
                        seq_kwargs={'c':'gray', 's':20,'marker':'o'},
                        cmap='RdBu',
                        cbar=True,
                        #clim = [-5,1],
                        cmap_size='2%',
                        cmap_pad=.3,
                        ccenter=0)

# Style colorbar
cb.set_label('Additive effect - WT gauge ($\\theta$)',
             labelpad=10, ha='center', va='center', rotation=-90)
cb.outline.set_visible(False)
cb.ax.tick_params(direction='in', size=20, color='white')
ax.set_title('Exponential enrichment - binding')


fig.tight_layout()
fig.savefig('plots/GRB2_SH3/lehner_GP_map_binding.png',dpi=300,bbox_inches='tight')

# %%
# Create grid in phi space
phi_lim = [-5, 5]
phi_grid = np.linspace(phi_lim[0], phi_lim[1], 1000)

# Create array of allowable y values
Y = mp_DM.Y    # Y = number of bins
y_lim = [-.5, Y-.5]
y_all = range(Y)

# Compute matrix of p(y|phi) values



# Create figure with two panels
fig, axs = plt.subplots(1,2,figsize=[12,6])

ax = axs[0]
# Right panel: draw measurement process as heatmap

measurement_process = mp_DM.p_of_y_given_phi(y_all, phi_grid)
im = ax.imshow(measurement_process,
               cmap='Greens',
               extent=phi_lim+y_lim,
               vmin=0,
               origin='lower',
               interpolation='nearest',
               aspect="auto")
ax.set_yticks(y_all)
ax.set_ylabel('bin number (y)')
ax.set_xlabel('latent phenotype ($\phi$)')
ax.set_title('measurement process - discrete monotonic')
cb = plt.colorbar(im,ax=ax)
cb.set_label('probability  $p(y|\phi)$', rotation=-90, va="bottom")

ax = axs[1]
# Right panel: draw measurement process as heatmap

measurement_process = mp_EE.p_of_y_given_phi(y_all, phi_grid)
im = ax.imshow(measurement_process,
               cmap='Greens',
               extent=phi_lim+y_lim,
               vmin=0,
               origin='lower',
               interpolation='nearest',
               aspect="auto")
ax.set_yticks(y_all)
ax.set_ylabel('bin number (y)')
ax.set_xlabel('latent phenotype ($\phi$)')
ax.set_title('measurement process - Exponential enrichment')
cb = plt.colorbar(im,ax=ax)
cb.set_label('probability  $p(y|\phi)$', rotation=-90, va="bottom")


fig.tight_layout()
fig.savefig('plots/GRB2_SH3/lehner_measurment_prcoess_binding.png',dpi=300,bbox_inches='tight')

# %%
data_df_GE = binding_df_full[['aa_seq','fitness']].copy()

# %%
plt.hist(data_df_GE['fitness'],bins=20,color='blue')
plt.show()

# %%
gpmapGE = mavenn.gpmap.AdditiveGPMapLayer(L, alphabet)
mp_GE = mavenn.measurement_process_layers.GlobalEpsitasisMP(K=50,
                                                           monotonic=True,
                                                           ge_heteroskedasticity_order=2,
                                                           ge_noise_model_type='Gaussian')

# %%
from sklearn.model_selection import train_test_split

# split data into training and testing sets
x_train_GE, x_test_GE, y_train_GE, y_test_GE = train_test_split(data_df_GE['aa_seq'].values, 
                                                                data_df_GE['fitness'].values, test_size=0.1)

# %%
model_GE = mavenn.Model2(gpmap=gpmapGE,
                      mp_list=[mp_GE])

# Set training data
model_GE.set_data(x=x_train_GE,
               #y_list=[data_df['y'].values.reshape(-1,1)],
               y_list=[y_train_GE.reshape(-1,1)],
               shuffle=False)
# Out:
# N = 41,749 observations set as training data.
# Using 19.8% for validation.
# Time to set data: 2.01 sec.

# %%
# Fit model to data
history = model_GE.fit(learning_rate=.0005,
                    epochs=150,
                    batch_size=300,
                    try_tqdm=False,
                    early_stopping=False,
                    early_stopping_patience=5,
                    linear_initialization=False)
# Out:
# Epoch 1/150
# 112/112 [==============================] - 3s 9ms/step - loss: 275.1065 - I_var: -1.1106 - val_loss: 258.2504 - val_I_var: -1.0377
# Epoch 2/150
# 112/112 [==============================] - 1s 6ms/step - loss: 247.2850 - I_var: -0.9765 - val_loss: 232.7896 - val_I_var: -0.9140
# Epoch 3/150
# 112/112 [==============================] - 1s 5ms/step - loss: 222.1268 - I_var: -0.8555 - val_loss: 207.8820 - val_I_var: -0.7930
# Epoch 4/150
# 112/112 [==============================] - 1s 5ms/step - loss: 195.5117 - I_var: -0.7271 - val_loss: 178.9848 - val_I_var: -0.6526
# Epoch 5/150
# 112/112 [==============================] - 1s 5ms/step - loss: 164.0232 - I_var: -0.5749 - val_loss: 145.9333 - val_I_var: -0.4920
# Epoch 6/150
# 112/112 [==============================] - 1s 5ms/step - loss: 131.8198 - I_var: -0.4198 - val_loss: 114.8364 - val_I_var: -0.3411
# Epoch 7/150
# 112/112 [==============================] - 1s 5ms/step - loss: 101.2712 - I_var: -0.2730 - val_loss: 85.5397 - val_I_var: -0.1989
# Epoch 8/150
# 112/112 [==============================] - 1s 5ms/step - loss: 73.1080 - I_var: -0.1371 - val_loss: 59.0751 - val_I_var: -0.0705
# Epoch 9/150
# 112/112 [==============================] - 0s 4ms/step - loss: 47.5233 - I_var: -0.0138 - val_loss: 35.1344 - val_I_var: 0.0458
# Epoch 10/150
# 112/112 [==============================] - 1s 5ms/step - loss: 24.5099 - I_var: 0.0970 - val_loss: 13.5453 - val_I_var: 0.1506
# Epoch 11/150
# 112/112 [==============================] - 1s 5ms/step - loss: 4.5265 - I_var: 0.1935 - val_loss: -3.2991 - val_I_var: 0.2324
# Epoch 12/150
# 112/112 [==============================] - 1s 5ms/step - loss: -12.2695 - I_var: 0.2739 - val_loss: -18.0427 - val_I_var: 0.3039
# Epoch 13/150
# 112/112 [==============================] - 1s 7ms/step - loss: -27.2557 - I_var: 0.3464 - val_loss: -32.2403 - val_I_var: 0.3730
# Epoch 14/150
# 112/112 [==============================] - 1s 5ms/step - loss: -39.5821 - I_var: 0.4053 - val_loss: -44.0401 - val_I_var: 0.4302
# Epoch 15/150
# 112/112 [==============================] - 1s 5ms/step - loss: -49.3367 - I_var: 0.4531 - val_loss: -49.3361 - val_I_var: 0.4557
# Epoch 16/150
# 112/112 [==============================] - 1s 5ms/step - loss: -57.3865 - I_var: 0.4917 - val_loss: -58.6935 - val_I_var: 0.5010
# Epoch 17/150
# 112/112 [==============================] - 1s 5ms/step - loss: -64.1070 - I_var: 0.5238 - val_loss: -64.0148 - val_I_var: 0.5268
# Epoch 18/150
# 112/112 [==============================] - 1s 5ms/step - loss: -68.3046 - I_var: 0.5445 - val_loss: -68.6262 - val_I_var: 0.5492
# Epoch 19/150
# 112/112 [==============================] - 1s 7ms/step - loss: -73.8470 - I_var: 0.5708 - val_loss: -70.0102 - val_I_var: 0.5562
# Epoch 20/150
# 112/112 [==============================] - 1s 5ms/step - loss: -77.7811 - I_var: 0.5893 - val_loss: -75.8100 - val_I_var: 0.5840
# Epoch 21/150
# 112/112 [==============================] - 1s 5ms/step - loss: -81.3811 - I_var: 0.6067 - val_loss: -74.2135 - val_I_var: 0.5768
# Epoch 22/150
# 112/112 [==============================] - 1s 5ms/step - loss: -84.8714 - I_var: 0.6240 - val_loss: -82.9341 - val_I_var: 0.6186
# Epoch 23/150
# 112/112 [==============================] - 1s 5ms/step - loss: -88.9669 - I_var: 0.6434 - val_loss: -85.4515 - val_I_var: 0.6307
# Epoch 24/150
# 112/112 [==============================] - 1s 5ms/step - loss: -92.8544 - I_var: 0.6631 - val_loss: -88.9935 - val_I_var: 0.6479
# Epoch 25/150
# 112/112 [==============================] - 1s 6ms/step - loss: -96.4651 - I_var: 0.6815 - val_loss: -92.8377 - val_I_var: 0.6666
# Epoch 26/150
# 112/112 [==============================] - 1s 7ms/step - loss: -100.6569 - I_var: 0.7009 - val_loss: -92.8398 - val_I_var: 0.6671
# Epoch 27/150
# 112/112 [==============================] - 0s 4ms/step - loss: -104.3763 - I_var: 0.7178 - val_loss: -100.3696 - val_I_var: 0.7032
# Epoch 28/150
# 112/112 [==============================] - 0s 4ms/step - loss: -108.6311 - I_var: 0.7391 - val_loss: -103.7223 - val_I_var: 0.7192
# Epoch 29/150
# 112/112 [==============================] - 0s 4ms/step - loss: -112.4057 - I_var: 0.7576 - val_loss: -107.2319 - val_I_var: 0.7366
# Epoch 30/150
# 112/112 [==============================] - 0s 4ms/step - loss: -116.2814 - I_var: 0.7757 - val_loss: -109.4702 - val_I_var: 0.7471
# Epoch 31/150
# 112/112 [==============================] - 1s 5ms/step - loss: -120.8566 - I_var: 0.7982 - val_loss: -114.6280 - val_I_var: 0.7723
# Epoch 32/150
# 112/112 [==============================] - 1s 5ms/step - loss: -124.8000 - I_var: 0.8169 - val_loss: -116.3817 - val_I_var: 0.7811
# Epoch 33/150
# 112/112 [==============================] - 0s 4ms/step - loss: -128.7026 - I_var: 0.8350 - val_loss: -121.7204 - val_I_var: 0.8067
# Epoch 34/150
# 112/112 [==============================] - 0s 4ms/step - loss: -132.4749 - I_var: 0.8537 - val_loss: -124.6447 - val_I_var: 0.8206
# Epoch 35/150
# 112/112 [==============================] - 1s 5ms/step - loss: -135.2608 - I_var: 0.8680 - val_loss: -127.7936 - val_I_var: 0.8362
# Epoch 36/150
# 112/112 [==============================] - 0s 4ms/step - loss: -139.6514 - I_var: 0.8873 - val_loss: -130.7954 - val_I_var: 0.8507
# Epoch 37/150
# 112/112 [==============================] - 0s 4ms/step - loss: -142.0843 - I_var: 0.9007 - val_loss: -134.0447 - val_I_var: 0.8664
# Epoch 38/150
# 112/112 [==============================] - 0s 4ms/step - loss: -145.4159 - I_var: 0.9161 - val_loss: -136.4285 - val_I_var: 0.8778
# Epoch 39/150
# 112/112 [==============================] - 0s 4ms/step - loss: -148.4495 - I_var: 0.9307 - val_loss: -137.8042 - val_I_var: 0.8848
# Epoch 40/150
# 112/112 [==============================] - 0s 4ms/step - loss: -151.5831 - I_var: 0.9464 - val_loss: -141.5491 - val_I_var: 0.9027
# Epoch 41/150
# 112/112 [==============================] - 0s 4ms/step - loss: -154.4193 - I_var: 0.9599 - val_loss: -140.6871 - val_I_var: 0.8987
# Epoch 42/150
# 112/112 [==============================] - 0s 4ms/step - loss: -156.4475 - I_var: 0.9695 - val_loss: -145.3775 - val_I_var: 0.9213
# Epoch 43/150
# 112/112 [==============================] - 0s 4ms/step - loss: -159.2025 - I_var: 0.9826 - val_loss: -147.0707 - val_I_var: 0.9295
# Epoch 44/150
# 112/112 [==============================] - 1s 5ms/step - loss: -160.9893 - I_var: 0.9918 - val_loss: -148.1936 - val_I_var: 0.9349
# Epoch 45/150
# 112/112 [==============================] - 0s 4ms/step - loss: -163.1826 - I_var: 1.0016 - val_loss: -140.8557 - val_I_var: 0.8990
# Epoch 46/150
# 112/112 [==============================] - 0s 4ms/step - loss: -163.5447 - I_var: 1.0041 - val_loss: -151.4598 - val_I_var: 0.9505
# Epoch 47/150
# 112/112 [==============================] - 0s 4ms/step - loss: -166.5151 - I_var: 1.0175 - val_loss: -152.0875 - val_I_var: 0.9535
# Epoch 48/150
# 112/112 [==============================] - 0s 4ms/step - loss: -167.3443 - I_var: 1.0203 - val_loss: -150.9689 - val_I_var: 0.9480
# Epoch 49/150
# 112/112 [==============================] - 0s 4ms/step - loss: -168.9272 - I_var: 1.0289 - val_loss: -154.4560 - val_I_var: 0.9650
# Epoch 50/150
# 112/112 [==============================] - 0s 4ms/step - loss: -170.0996 - I_var: 1.0349 - val_loss: -155.0205 - val_I_var: 0.9677
# Epoch 51/150
# 112/112 [==============================] - 0s 4ms/step - loss: -170.9112 - I_var: 1.0379 - val_loss: -152.1431 - val_I_var: 0.9538
# Epoch 52/150
# 112/112 [==============================] - 0s 4ms/step - loss: -171.6119 - I_var: 1.0418 - val_loss: -155.9091 - val_I_var: 0.9720
# Epoch 53/150
# 112/112 [==============================] - 1s 5ms/step - loss: -172.7211 - I_var: 1.0474 - val_loss: -156.8450 - val_I_var: 0.9765
# Epoch 54/150
# 112/112 [==============================] - 0s 4ms/step - loss: -173.5761 - I_var: 1.0517 - val_loss: -157.3206 - val_I_var: 0.9788
# Epoch 55/150
# 112/112 [==============================] - 1s 5ms/step - loss: -173.1280 - I_var: 1.0498 - val_loss: -156.8685 - val_I_var: 0.9765
# Epoch 56/150
# 112/112 [==============================] - 0s 4ms/step - loss: -174.7436 - I_var: 1.0574 - val_loss: -156.2173 - val_I_var: 0.9734
# Epoch 57/150
# 112/112 [==============================] - 1s 7ms/step - loss: -174.7094 - I_var: 1.0568 - val_loss: -152.7422 - val_I_var: 0.9569
# Epoch 58/150
# 112/112 [==============================] - 1s 7ms/step - loss: -175.4138 - I_var: 1.0603 - val_loss: -154.9720 - val_I_var: 0.9676
# Epoch 59/150
# 112/112 [==============================] - 1s 5ms/step - loss: -175.9628 - I_var: 1.0644 - val_loss: -157.5136 - val_I_var: 0.9797
# Epoch 60/150
# 112/112 [==============================] - 1s 5ms/step - loss: -176.3163 - I_var: 1.0654 - val_loss: -158.8857 - val_I_var: 0.9862
# Epoch 61/150
# 112/112 [==============================] - 1s 7ms/step - loss: -177.1568 - I_var: 1.0690 - val_loss: -158.3848 - val_I_var: 0.9839
# Epoch 62/150
# 112/112 [==============================] - 1s 6ms/step - loss: -177.1955 - I_var: 1.0696 - val_loss: -158.4885 - val_I_var: 0.9843
# Epoch 63/150
# 112/112 [==============================] - 1s 6ms/step - loss: -177.4032 - I_var: 1.0697 - val_loss: -158.2766 - val_I_var: 0.9833
# Epoch 64/150
# 112/112 [==============================] - 1s 6ms/step - loss: -177.4907 - I_var: 1.0714 - val_loss: -159.1770 - val_I_var: 0.9875
# Epoch 65/150
# 112/112 [==============================] - 0s 4ms/step - loss: -177.6416 - I_var: 1.0704 - val_loss: -157.4866 - val_I_var: 0.9793
# Epoch 66/150
# 112/112 [==============================] - 1s 6ms/step - loss: -178.1824 - I_var: 1.0740 - val_loss: -158.8624 - val_I_var: 0.9860
# Epoch 67/150
# 112/112 [==============================] - 1s 5ms/step - loss: -178.1592 - I_var: 1.0725 - val_loss: -159.3001 - val_I_var: 0.9881
# Epoch 68/150
# 112/112 [==============================] - 0s 4ms/step - loss: -178.7090 - I_var: 1.0749 - val_loss: -159.3599 - val_I_var: 0.9884
# Epoch 69/150
# 112/112 [==============================] - 1s 5ms/step - loss: -178.9240 - I_var: 1.0778 - val_loss: -157.8567 - val_I_var: 0.9811
# Epoch 70/150
# 112/112 [==============================] - 1s 5ms/step - loss: -178.4723 - I_var: 1.0766 - val_loss: -158.6110 - val_I_var: 0.9845
# Epoch 71/150
# 112/112 [==============================] - 1s 5ms/step - loss: -179.2834 - I_var: 1.0788 - val_loss: -159.3952 - val_I_var: 0.9883
# Epoch 72/150
# 112/112 [==============================] - 1s 5ms/step - loss: -178.9303 - I_var: 1.0776 - val_loss: -159.8422 - val_I_var: 0.9905
# Epoch 73/150
# 112/112 [==============================] - 1s 5ms/step - loss: -178.9460 - I_var: 1.0776 - val_loss: -159.4587 - val_I_var: 0.9888
# Epoch 74/150
# 112/112 [==============================] - 1s 5ms/step - loss: -179.4189 - I_var: 1.0791 - val_loss: -155.8670 - val_I_var: 0.9712
# Epoch 75/150
# 112/112 [==============================] - 1s 5ms/step - loss: -179.6148 - I_var: 1.0818 - val_loss: -159.9621 - val_I_var: 0.9912
# Epoch 76/150
# 112/112 [==============================] - 1s 5ms/step - loss: -179.9688 - I_var: 1.0822 - val_loss: -158.2029 - val_I_var: 0.9826
# Epoch 77/150
# 112/112 [==============================] - 1s 6ms/step - loss: -180.0659 - I_var: 1.0841 - val_loss: -159.8611 - val_I_var: 0.9906
# Epoch 78/150
# 112/112 [==============================] - 1s 10ms/step - loss: -180.1439 - I_var: 1.0831 - val_loss: -157.8435 - val_I_var: 0.9809
# Epoch 79/150
# 112/112 [==============================] - 1s 7ms/step - loss: -180.1194 - I_var: 1.0839 - val_loss: -159.3837 - val_I_var: 0.9885
# Epoch 80/150
# 112/112 [==============================] - 1s 9ms/step - loss: -180.4598 - I_var: 1.0839 - val_loss: -159.9825 - val_I_var: 0.9912
# Epoch 81/150
# 112/112 [==============================] - 1s 10ms/step - loss: -180.0570 - I_var: 1.0823 - val_loss: -159.1673 - val_I_var: 0.9873
# Epoch 82/150
# 112/112 [==============================] - 1s 9ms/step - loss: -180.6780 - I_var: 1.0856 - val_loss: -158.2876 - val_I_var: 0.9829
# Epoch 83/150
# 112/112 [==============================] - 1s 7ms/step - loss: -180.3675 - I_var: 1.0845 - val_loss: -159.7713 - val_I_var: 0.9900
# Epoch 84/150
# 112/112 [==============================] - 1s 5ms/step - loss: -180.7029 - I_var: 1.0853 - val_loss: -159.6060 - val_I_var: 0.9892
# Epoch 85/150
# 112/112 [==============================] - 1s 5ms/step - loss: -180.6781 - I_var: 1.0851 - val_loss: -160.4321 - val_I_var: 0.9934
# Epoch 86/150
# 112/112 [==============================] - 1s 5ms/step - loss: -180.6935 - I_var: 1.0858 - val_loss: -159.8421 - val_I_var: 0.9904
# Epoch 87/150
# 112/112 [==============================] - 1s 5ms/step - loss: -180.5528 - I_var: 1.0845 - val_loss: -159.4450 - val_I_var: 0.9884
# Epoch 88/150
# 112/112 [==============================] - 1s 5ms/step - loss: -180.5077 - I_var: 1.0860 - val_loss: -160.0938 - val_I_var: 0.9915
# Epoch 89/150
# 112/112 [==============================] - 1s 5ms/step - loss: -181.2457 - I_var: 1.0886 - val_loss: -160.2782 - val_I_var: 0.9925
# Epoch 90/150
# 112/112 [==============================] - 1s 5ms/step - loss: -180.5297 - I_var: 1.0860 - val_loss: -160.2590 - val_I_var: 0.9924
# Epoch 91/150
# 112/112 [==============================] - 1s 6ms/step - loss: -181.5827 - I_var: 1.0881 - val_loss: -159.6026 - val_I_var: 0.9891
# Epoch 92/150
# 112/112 [==============================] - 1s 5ms/step - loss: -181.2072 - I_var: 1.0892 - val_loss: -160.3281 - val_I_var: 0.9927
# Epoch 93/150
# 112/112 [==============================] - 1s 5ms/step - loss: -181.1198 - I_var: 1.0848 - val_loss: -157.7925 - val_I_var: 0.9806
# Epoch 94/150
# 112/112 [==============================] - 1s 5ms/step - loss: -181.3817 - I_var: 1.0895 - val_loss: -159.4770 - val_I_var: 0.9887
# Epoch 95/150
# 112/112 [==============================] - 1s 5ms/step - loss: -181.4791 - I_var: 1.0907 - val_loss: -158.3188 - val_I_var: 0.9831
# Epoch 96/150
# 112/112 [==============================] - 1s 6ms/step - loss: -181.3172 - I_var: 1.0883 - val_loss: -160.2487 - val_I_var: 0.9924
# Epoch 97/150
# 112/112 [==============================] - 1s 5ms/step - loss: -181.6331 - I_var: 1.0907 - val_loss: -160.3136 - val_I_var: 0.9926
# Epoch 98/150
# 112/112 [==============================] - 1s 6ms/step - loss: -181.3583 - I_var: 1.0882 - val_loss: -155.6167 - val_I_var: 0.9700
# Epoch 99/150
# 112/112 [==============================] - 1s 5ms/step - loss: -181.7926 - I_var: 1.0907 - val_loss: -160.5674 - val_I_var: 0.9938
# Epoch 100/150
# 112/112 [==============================] - 1s 6ms/step - loss: -180.9781 - I_var: 1.0881 - val_loss: -160.7241 - val_I_var: 0.9945
# Epoch 101/150
# 112/112 [==============================] - 1s 6ms/step - loss: -182.0727 - I_var: 1.0922 - val_loss: -160.2857 - val_I_var: 0.9924
# Epoch 102/150
# 112/112 [==============================] - 1s 5ms/step - loss: -181.4445 - I_var: 1.0878 - val_loss: -157.0090 - val_I_var: 0.9768
# Epoch 103/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.2057 - I_var: 1.0912 - val_loss: -160.5758 - val_I_var: 0.9938
# Epoch 104/150
# 112/112 [==============================] - 1s 5ms/step - loss: -181.6114 - I_var: 1.0915 - val_loss: -160.9182 - val_I_var: 0.9955
# Epoch 105/150
# 112/112 [==============================] - 1s 5ms/step - loss: -181.9492 - I_var: 1.0923 - val_loss: -159.2903 - val_I_var: 0.9877
# Epoch 106/150
# 112/112 [==============================] - 1s 5ms/step - loss: -181.6816 - I_var: 1.0916 - val_loss: -160.2849 - val_I_var: 0.9925
# Epoch 107/150
# 112/112 [==============================] - 0s 4ms/step - loss: -181.6027 - I_var: 1.0915 - val_loss: -160.7682 - val_I_var: 0.9948
# Epoch 108/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.1729 - I_var: 1.0930 - val_loss: -160.7866 - val_I_var: 0.9949
# Epoch 109/150
# 112/112 [==============================] - 1s 4ms/step - loss: -181.5949 - I_var: 1.0898 - val_loss: -160.7527 - val_I_var: 0.9946
# Epoch 110/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.6730 - I_var: 1.0957 - val_loss: -160.8821 - val_I_var: 0.9953
# Epoch 111/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.0196 - I_var: 1.0920 - val_loss: -159.8602 - val_I_var: 0.9903
# Epoch 112/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.6942 - I_var: 1.0940 - val_loss: -160.8971 - val_I_var: 0.9953
# Epoch 113/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.5326 - I_var: 1.0948 - val_loss: -159.8230 - val_I_var: 0.9903
# Epoch 114/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.8094 - I_var: 1.0950 - val_loss: -160.4412 - val_I_var: 0.9930
# Epoch 115/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.3425 - I_var: 1.0947 - val_loss: -158.9722 - val_I_var: 0.9860
# Epoch 116/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.3164 - I_var: 1.0942 - val_loss: -158.0362 - val_I_var: 0.9816
# Epoch 117/150
# 112/112 [==============================] - 0s 4ms/step - loss: -182.7482 - I_var: 1.0958 - val_loss: -160.8541 - val_I_var: 0.9950
# Epoch 118/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.6271 - I_var: 1.0946 - val_loss: -159.3875 - val_I_var: 0.9880
# Epoch 119/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.4347 - I_var: 1.0936 - val_loss: -160.8015 - val_I_var: 0.9948
# Epoch 120/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.6137 - I_var: 1.0958 - val_loss: -160.9398 - val_I_var: 0.9955
# Epoch 121/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.3342 - I_var: 1.0936 - val_loss: -159.3463 - val_I_var: 0.9880
# Epoch 122/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.2892 - I_var: 1.0930 - val_loss: -160.5536 - val_I_var: 0.9938
# Epoch 123/150
# 112/112 [==============================] - 1s 5ms/step - loss: -183.0755 - I_var: 1.0968 - val_loss: -160.0722 - val_I_var: 0.9914
# Epoch 124/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.9866 - I_var: 1.0970 - val_loss: -159.4525 - val_I_var: 0.9885
# Epoch 125/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.6248 - I_var: 1.0956 - val_loss: -159.6956 - val_I_var: 0.9896
# Epoch 126/150
# 112/112 [==============================] - 1s 5ms/step - loss: -183.1559 - I_var: 1.0973 - val_loss: -158.9137 - val_I_var: 0.9855
# Epoch 127/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.9570 - I_var: 1.0968 - val_loss: -157.2992 - val_I_var: 0.9778
# Epoch 128/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.5933 - I_var: 1.0946 - val_loss: -160.9274 - val_I_var: 0.9955
# Epoch 129/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.9741 - I_var: 1.0958 - val_loss: -161.1676 - val_I_var: 0.9966
# Epoch 130/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.3995 - I_var: 1.0934 - val_loss: -159.8878 - val_I_var: 0.9904
# Epoch 131/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.5180 - I_var: 1.0925 - val_loss: -155.4230 - val_I_var: 0.9689
# Epoch 132/150
# 112/112 [==============================] - 1s 5ms/step - loss: -183.1239 - I_var: 1.0982 - val_loss: -159.4279 - val_I_var: 0.9884
# Epoch 133/150
# 112/112 [==============================] - 1s 5ms/step - loss: -183.2481 - I_var: 1.0976 - val_loss: -161.0559 - val_I_var: 0.9961
# Epoch 134/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.8578 - I_var: 1.0965 - val_loss: -159.8065 - val_I_var: 0.9902
# Epoch 135/150
# 112/112 [==============================] - 1s 5ms/step - loss: -183.1672 - I_var: 1.0963 - val_loss: -158.6699 - val_I_var: 0.9844
# Epoch 136/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.8753 - I_var: 1.0967 - val_loss: -160.8912 - val_I_var: 0.9954
# Epoch 137/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.3544 - I_var: 1.0941 - val_loss: -160.9606 - val_I_var: 0.9956
# Epoch 138/150
# 112/112 [==============================] - 1s 5ms/step - loss: -183.0183 - I_var: 1.0974 - val_loss: -159.8779 - val_I_var: 0.9905
# Epoch 139/150
# 112/112 [==============================] - 1s 5ms/step - loss: -183.4309 - I_var: 1.0983 - val_loss: -160.6468 - val_I_var: 0.9942
# Epoch 140/150
# 112/112 [==============================] - 1s 5ms/step - loss: -183.1451 - I_var: 1.0968 - val_loss: -160.4279 - val_I_var: 0.9932
# Epoch 141/150
# 112/112 [==============================] - 1s 5ms/step - loss: -183.2943 - I_var: 1.0989 - val_loss: -161.0874 - val_I_var: 0.9962
# Epoch 142/150
# 112/112 [==============================] - 1s 5ms/step - loss: -183.1034 - I_var: 1.0978 - val_loss: -161.3296 - val_I_var: 0.9974
# Epoch 143/150
# 112/112 [==============================] - 1s 5ms/step - loss: -183.7400 - I_var: 1.1007 - val_loss: -161.4570 - val_I_var: 0.9980
# Epoch 144/150
# 112/112 [==============================] - 1s 5ms/step - loss: -183.2175 - I_var: 1.0972 - val_loss: -156.1922 - val_I_var: 0.9724
# Epoch 145/150
# 112/112 [==============================] - 1s 5ms/step - loss: -182.7213 - I_var: 1.0945 - val_loss: -161.5718 - val_I_var: 0.9985
# Epoch 146/150
# 112/112 [==============================] - 1s 6ms/step - loss: -183.6957 - I_var: 1.1012 - val_loss: -160.8940 - val_I_var: 0.9954
# Epoch 147/150
# 112/112 [==============================] - 1s 5ms/step - loss: -183.5938 - I_var: 1.1010 - val_loss: -161.2988 - val_I_var: 0.9973
# Epoch 148/150
# 112/112 [==============================] - 1s 5ms/step - loss: -183.3042 - I_var: 1.0990 - val_loss: -160.5963 - val_I_var: 0.9940
# Epoch 149/150
# 112/112 [==============================] - 1s 5ms/step - loss: -183.1650 - I_var: 1.0985 - val_loss: -160.9504 - val_I_var: 0.9955
# Epoch 150/150
# 112/112 [==============================] - 1s 7ms/step - loss: -183.5159 - I_var: 1.0999 - val_loss: -161.4397 - val_I_var: 0.9979
# Training time: 88.2 seconds

# %%
# Show training history
print('On test data:')
# x_test = test_df['x'].values
# y_test = test_df[y_cols].values


I_var_hist = model_GE.history['I_var']
val_I_var_hist = model_GE.history['val_I_var']

fig, axs = plt.subplots(1,2,figsize=[8,4])

ax = axs[0]
ax.plot(I_var_hist, label='I_var_train')
ax.plot(val_I_var_hist, label='I_var_val')
ax.legend()
ax.set_xlabel('epochs')
ax.set_ylabel('bits')
#ax.set_xscale('log')
ax.set_title('training hisotry')

ax = axs[1]
ax.plot(model_GE.history['loss'], label='loss_train')
ax.plot(model_GE.history['val_loss'], label='loss_val')
# ax.set_xlim(100,300)
# ax.set_ylim(0.7*1e6,0.8*1e6)
ax.legend()
ax.set_xlabel('epochs')
ax.set_ylabel('loss')
# ax.set_xscale('log')
# ax.set_yscale('log')
ax.set_title('training hisotry')
fig.tight_layout()
# Out:
# On test data:

# %%
phi = gpmapGE.x_to_phi(x_test_GE)

# %%
fig, axs = plt.subplots(1,2, figsize=(9,4.5))

ax = axs[0]
yhat = mp_GE.phi_to_yhat(phi)
ax.scatter(phi,y_test_GE,s=2,alpha=0.2,c='b',label='test data')
#ax.scatter(phi,yhat* model.y_std+model.y_mean,s=1,alpha=0.1,c='r',label='$\hat{y} = g(\phi)$')
ax.scatter(phi,yhat,s=2,alpha=0.3,c='r',label='$\hat{y} = g(\phi)$')

ax.set_xlabel('latent phenotype ($\phi$)')
ax.set_ylabel('measurement ($y$)')
ax.set_title('GRB2-SH3')
leg = ax.legend()

for lh in leg.legendHandles: 
    lh.set_alpha(1)
    
    
ax = axs[1]
ax.scatter(yhat,y_test_GE,s=2,alpha=0.2,c='b',label='test data')
Rsq = np.corrcoef(yhat.numpy().ravel(),y_test_GE)[0,1]**2

ax.set_xlabel('$\hat{y} = g(\phi)$')
ax.set_ylabel('measurement ($y$)')
ax.set_title(f'GRB2-SH3, $R^2 = $ {Rsq:.3f}')
leg = ax.legend()

for lh in leg.legendHandles: 
    lh.set_alpha(1)

fig.tight_layout()

# %%
theta_lc_GE = gpmapGE.get_theta(model_GE,gauge='consensus')['theta_lc']

# %%
plt.figure(figsize=(5,5))
plt.scatter(theta_lc_DM.ravel(),theta_lc_GE.ravel(),c='blue',s=5,alpha=0.3)
plt.xlabel('Theta discrete monotonic')
plt.ylabel('Theta global epistasis')
# Out:
# Text(0, 0.5, 'Theta global epistasis')
