# %%
import mavenn

# %%
mpsa_model = mavenn.load_example_model('mpsa_ge_additive')
# Out:
# Model loaded from these files:
# 	/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mavenn/examples/models/mpsa_ge_additive.pickle
# 	/Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/mavenn/examples/models/mpsa_ge_additive.h5

# %%
#mpsa_model.get_theta()['logomaker_df'].fillna(0).to_csv('data/mpsa_ge_additive_theta.csv')

# %%
mpsa_model.get_theta()
# Out:
# {'L': 9,
#  'C': 4,
#  'alphabet': array(['A', 'C', 'G', 'U'], dtype='<U1'),
#  'theta_0': -2.508132402430794,
#  'theta_lc': array([[ 0.18999692,  0.24595671, -0.21543635, -0.22279311],
#         [ 0.48625791, -0.03100507, -0.20798812, -0.24648926],
#         [-0.325754  , -0.31585277,  1.07088815, -0.43752224],
#         [        nan,         nan,  0.        ,         nan],
#         [        nan, -0.91113895,         nan,  0.94125545],
#         [ 0.94310597, -0.49581345,  0.13203739, -0.53594949],
#         [ 0.49934939, -0.03249248, -0.29418721, -0.18975388],
#         [-0.23027135, -0.3300365 ,  0.74894776, -0.26176081],
#         [-0.15922378, -0.08353693, -0.0976538 ,  0.31999839]]),
#  'theta_lclc': array([[[[nan, nan, nan, nan],
#           [nan, nan, nan, nan],
#           [nan, nan, nan, nan],
#           ...,
#           [nan, nan, nan, nan],
#           [nan, nan, nan, nan],
#           [nan, nan, nan, nan]],
#
#          [[nan, nan, nan, nan],
# ...
