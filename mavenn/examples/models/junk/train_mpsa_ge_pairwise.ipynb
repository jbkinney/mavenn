# %%
# Standard imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time

# Insert path to mavenn beginning of path
import os
import sys
# Load mavenn
import sys
path_to_mavenn = '/Users/tareen/Desktop/Research_Projects/2020_mavenn_github/mavenn_git_ssh/'
sys.path.insert(0, path_to_mavenn)

# Load mavenn
import mavenn
print(mavenn.__path__)
# Out:
# ['/Users/tareen/Desktop/Research_Projects/2020_mavenn_github/mavenn_git_ssh/mavenn']

# %%
# Download mpsa dataset from master branch
url = 'https://github.com/jbkinney/mavenn/blob/master/mavenn/examples/datasets/mpsa_data.csv.gz?raw=true'

data_df = pd.read_csv(url,  
                      compression='gzip',
                      index_col=[0])

data_df = data_df.reset_index().copy()

# Separate test from data_df
ix_test = data_df['set']=='test'
test_df = data_df[ix_test].reset_index(drop=True)
print(f'test N: {len(test_df):,}')

# Remove test data from data_df
data_df = data_df[~ix_test].reset_index(drop=True)
print(f'training + validation N: {len(data_df):,}')
data_df.head(10)
# Out:
# test N: 6,249
# training + validation N: 24,234
#           set  tot_ct  ex_ct         y          x
# 0    training      28      2  0.023406  GGAGUGAUG
# 1    training     315      7 -0.587914  AGUGUGCAA
# 2  validation      27      0 -0.438475  UAAGCUUUU
# 3    training     130      2 -0.631467  AUGGUCGGG
# 4    training     552     19 -0.433012  AGGGCAGGA
# 5    training     151    184  1.094011  AAGGUCCGC
# 6    training      88      4 -0.241737  CAGGCAAAC
# 7    training     105      5 -0.238471  GUGGCAAAU
# 8  validation      14      0 -0.167408  CAUGCAGCU
# 9    training     170     14 -0.048222  CAAGUCACU

# %%
# Get sequence length
L = len(data_df['x'][0])

# Define model
model = mavenn.Model(L=L,
                     alphabet='rna',
                     gpmap_type='pairwise', 
                     regression_type='GE',
                     theta_regularization=0.1,
                     ge_noise_model_type='SkewedT',
                     ge_heteroskedasticity_order=2)

# %%
# Set training data
model.set_data(x=data_df['x'],
               y=data_df['y'],
               validation_flags=(data_df['set']=='validation'),
               shuffle=True)
# Out:
# N = 24,234 observations set as training data.
# Using 24.8% for validation.
# Data shuffled.
# Time to set data: 0.448 sec.

# %%
# Fit model to data
model.fit(learning_rate=.001,
          epochs=1000,
          batch_size=200,
          early_stopping=True,
          early_stopping_patience=30,
          linear_initialization=False)
# Out:
# Epoch 1/1000
# Using TensorFlow backend.
# Exception ignored in: <bound method tqdm.__del__ of <tqdm.auto.tqdm object at 0x7fde4822a828>>
# Traceback (most recent call last):
#   File "/Users/tareen/miniconda3/lib/python3.6/site-packages/tqdm/std.py", line 1147, in __del__
#     self.close()
#   File "/Users/tareen/miniconda3/lib/python3.6/site-packages/tqdm/notebook.py", line 289, in close
#     self.disp(bar_style='success', check_delay=False)
# AttributeError: 'tqdm' object has no attribute 'disp'
# 92/92 [==============================] - 4s 16ms/step - loss: 290.9010 - I_var: -0.5745 - val_loss: 258.1690 - val_I_var: -0.4546
# Epoch 2/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 253.7010 - I_var: -0.3890 - val_loss: 238.9287 - val_I_var: -0.3206
# Epoch 3/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 236.6159 - I_var: -0.2545 - val_loss: 220.0655 - val_I_var: -0.1894
# Epoch 4/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 216.4847 - I_var: -0.1361 - val_loss: 206.5412 - val_I_var: -0.0965
# Epoch 5/1000
# 92/92 [==============================] - 0s 3ms/step - loss: 202.8649 - I_var: -0.0536 - val_loss: 195.8232 - val_I_var: -0.0238
# Epoch 6/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 192.8565 - I_var: 0.0124 - val_loss: 186.7983 - val_I_var: 0.0370
# Epoch 7/1000
# 92/92 [==============================] - 0s 3ms/step - loss: 184.0677 - I_var: 0.0681 - val_loss: 179.0784 - val_I_var: 0.0896
# Epoch 8/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 177.6669 - I_var: 0.1138 - val_loss: 173.6125 - val_I_var: 0.1257
# Epoch 9/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 173.6714 - I_var: 0.1516 - val_loss: 170.6653 - val_I_var: 0.1475
# Epoch 10/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 171.1095 - I_var: 0.1737 - val_loss: 166.2874 - val_I_var: 0.1763
# Epoch 11/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 166.9890 - I_var: 0.1921 - val_loss: 164.4980 - val_I_var: 0.1872
# Epoch 12/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 167.1179 - I_var: 0.2027 - val_loss: 162.6771 - val_I_var: 0.2005
# Epoch 13/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 164.3494 - I_var: 0.2100 - val_loss: 161.8318 - val_I_var: 0.2058
# Epoch 14/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 161.2085 - I_var: 0.2217 - val_loss: 161.1462 - val_I_var: 0.2113
# Epoch 15/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 162.2641 - I_var: 0.2177 - val_loss: 160.6238 - val_I_var: 0.2144
# Epoch 16/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 162.9971 - I_var: 0.2275 - val_loss: 160.4589 - val_I_var: 0.2156
# Epoch 17/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 159.9944 - I_var: 0.2218 - val_loss: 160.2282 - val_I_var: 0.2174
# Epoch 18/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 159.6425 - I_var: 0.2238 - val_loss: 161.0354 - val_I_var: 0.2124
# Epoch 19/1000
# 92/92 [==============================] - 0s 3ms/step - loss: 161.1285 - I_var: 0.2279 - val_loss: 159.5210 - val_I_var: 0.2219
# Epoch 20/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 156.5658 - I_var: 0.2295 - val_loss: 159.2776 - val_I_var: 0.2236
# Epoch 21/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 159.6320 - I_var: 0.2290 - val_loss: 158.9763 - val_I_var: 0.2259
# Epoch 22/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 161.6180 - I_var: 0.2325 - val_loss: 158.8719 - val_I_var: 0.2267
# Epoch 23/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 160.8898 - I_var: 0.2348 - val_loss: 158.6987 - val_I_var: 0.2275
# Epoch 24/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 160.5146 - I_var: 0.2354 - val_loss: 158.6805 - val_I_var: 0.2289
# Epoch 25/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 159.2196 - I_var: 0.2409 - val_loss: 158.6397 - val_I_var: 0.2290
# Epoch 26/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 158.1997 - I_var: 0.2397 - val_loss: 157.9969 - val_I_var: 0.2333
# Epoch 27/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 157.7164 - I_var: 0.2399 - val_loss: 157.9751 - val_I_var: 0.2340
# Epoch 28/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 159.1452 - I_var: 0.2445 - val_loss: 157.6931 - val_I_var: 0.2354
# Epoch 29/1000
# 92/92 [==============================] - 0s 3ms/step - loss: 158.5301 - I_var: 0.2484 - val_loss: 157.7061 - val_I_var: 0.2361
# Epoch 30/1000
# 92/92 [==============================] - 0s 3ms/step - loss: 161.1883 - I_var: 0.2516 - val_loss: 158.2393 - val_I_var: 0.2307
# Epoch 31/1000
# 92/92 [==============================] - 0s 3ms/step - loss: 155.9789 - I_var: 0.2496 - val_loss: 157.1186 - val_I_var: 0.2399
# Epoch 32/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 158.1936 - I_var: 0.2563 - val_loss: 156.7876 - val_I_var: 0.2426
# Epoch 33/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 157.9884 - I_var: 0.2458 - val_loss: 156.6801 - val_I_var: 0.2432
# Epoch 34/1000
# 92/92 [==============================] - 0s 3ms/step - loss: 156.1734 - I_var: 0.2491 - val_loss: 157.1336 - val_I_var: 0.2395
# Epoch 35/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 159.0788 - I_var: 0.2532 - val_loss: 156.3486 - val_I_var: 0.2460
# Epoch 36/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 158.2536 - I_var: 0.2596 - val_loss: 156.1966 - val_I_var: 0.2471
# Epoch 37/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 158.8761 - I_var: 0.2561 - val_loss: 156.0779 - val_I_var: 0.2483
# Epoch 38/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 156.9593 - I_var: 0.2590 - val_loss: 155.8909 - val_I_var: 0.2500
# Epoch 39/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 156.0421 - I_var: 0.2578 - val_loss: 155.5422 - val_I_var: 0.2521
# Epoch 40/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 153.3392 - I_var: 0.2552 - val_loss: 155.7895 - val_I_var: 0.2500
# Epoch 41/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 159.2596 - I_var: 0.2603 - val_loss: 155.7715 - val_I_var: 0.2505
# Epoch 42/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 158.4902 - I_var: 0.2642 - val_loss: 155.4337 - val_I_var: 0.2518
# Epoch 43/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 158.7357 - I_var: 0.2588 - val_loss: 155.4278 - val_I_var: 0.2524
# Epoch 44/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 157.0956 - I_var: 0.2625 - val_loss: 154.9803 - val_I_var: 0.2565
# Epoch 45/1000
# 92/92 [==============================] - 1s 8ms/step - loss: 157.1219 - I_var: 0.2702 - val_loss: 155.1549 - val_I_var: 0.2539
# Epoch 46/1000
# 92/92 [==============================] - 1s 7ms/step - loss: 156.3725 - I_var: 0.2674 - val_loss: 154.4953 - val_I_var: 0.2595
# Epoch 47/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 152.8334 - I_var: 0.2673 - val_loss: 154.2702 - val_I_var: 0.2609
# Epoch 48/1000
# 92/92 [==============================] - 1s 5ms/step - loss: 155.8248 - I_var: 0.2604 - val_loss: 154.4835 - val_I_var: 0.2574
# Epoch 49/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 154.3753 - I_var: 0.2609 - val_loss: 154.0219 - val_I_var: 0.2626
# Epoch 50/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 157.7029 - I_var: 0.2724 - val_loss: 153.6451 - val_I_var: 0.2664
# Epoch 51/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 153.8633 - I_var: 0.2774 - val_loss: 153.4588 - val_I_var: 0.2674
# Epoch 52/1000
# 92/92 [==============================] - 0s 4ms/step - loss: 155.4114 - I_var: 0.2770 - val_loss: 153.9834 - val_I_var: 0.2619
# Epoch 53/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 154.3264 - I_var: 0.2729 - val_loss: 153.6992 - val_I_var: 0.2643
# Epoch 54/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 153.6058 - I_var: 0.2808 - val_loss: 153.5131 - val_I_var: 0.2660
# Epoch 55/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 153.6805 - I_var: 0.2824 - val_loss: 153.6003 - val_I_var: 0.2635
# Epoch 56/1000
# 92/92 [==============================] - 1s 7ms/step - loss: 153.3543 - I_var: 0.2858 - val_loss: 152.3340 - val_I_var: 0.2769
# Epoch 57/1000
# 92/92 [==============================] - 1s 7ms/step - loss: 153.8976 - I_var: 0.2858 - val_loss: 152.1078 - val_I_var: 0.2797
# Epoch 58/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 153.1867 - I_var: 0.2904 - val_loss: 151.5760 - val_I_var: 0.2794
# Epoch 59/1000
# 92/92 [==============================] - 1s 7ms/step - loss: 152.8280 - I_var: 0.2930 - val_loss: 151.0815 - val_I_var: 0.2850
# Epoch 60/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 152.4956 - I_var: 0.3005 - val_loss: 150.9352 - val_I_var: 0.2891
# Epoch 61/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 153.9510 - I_var: 0.2925 - val_loss: 152.8230 - val_I_var: 0.2784
# Epoch 62/1000
# 92/92 [==============================] - 1s 7ms/step - loss: 152.4720 - I_var: 0.2835 - val_loss: 149.8725 - val_I_var: 0.2944
# Epoch 63/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 151.9072 - I_var: 0.3043 - val_loss: 149.2023 - val_I_var: 0.3015
# Epoch 64/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 150.7206 - I_var: 0.3171 - val_loss: 150.3752 - val_I_var: 0.2959
# Epoch 65/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 150.1742 - I_var: 0.3326 - val_loss: 147.9785 - val_I_var: 0.3137
# Epoch 66/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 143.7570 - I_var: 0.3767 - val_loss: 149.2158 - val_I_var: 0.3028
# Epoch 67/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 149.6531 - I_var: 0.3076 - val_loss: 149.1837 - val_I_var: 0.3047
# Epoch 68/1000
# 92/92 [==============================] - 1s 7ms/step - loss: 151.0519 - I_var: 0.3046 - val_loss: 148.0783 - val_I_var: 0.3130
# Epoch 69/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 147.5215 - I_var: 0.3344 - val_loss: 146.0202 - val_I_var: 0.3277
# Epoch 70/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 303.7200 - I_var: -4.8876 - val_loss: 162.3437 - val_I_var: 0.2125
# Epoch 71/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 166.9826 - I_var: 0.2129 - val_loss: 160.6761 - val_I_var: 0.2201
# Epoch 72/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 162.4501 - I_var: 0.2369 - val_loss: 158.1321 - val_I_var: 0.2378
# Epoch 73/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 158.2521 - I_var: 0.2512 - val_loss: 156.2510 - val_I_var: 0.2510
# Epoch 74/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 155.4706 - I_var: 0.2533 - val_loss: 154.6131 - val_I_var: 0.2618
# Epoch 75/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 157.5830 - I_var: 0.2717 - val_loss: 153.4492 - val_I_var: 0.2694
# Epoch 76/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 156.5799 - I_var: 0.2856 - val_loss: 152.2911 - val_I_var: 0.2772
# Epoch 77/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 153.4479 - I_var: 0.2887 - val_loss: 151.6669 - val_I_var: 0.2816
# Epoch 78/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 153.9952 - I_var: 0.2830 - val_loss: 150.9626 - val_I_var: 0.2868
# Epoch 79/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 152.7611 - I_var: 0.2884 - val_loss: 150.6095 - val_I_var: 0.2893
# Epoch 80/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 152.7282 - I_var: 0.2998 - val_loss: 150.3236 - val_I_var: 0.2928
# Epoch 81/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 152.1104 - I_var: 0.3050 - val_loss: 149.7836 - val_I_var: 0.2968
# Epoch 82/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 150.5798 - I_var: 0.3008 - val_loss: 149.8759 - val_I_var: 0.2973
# Epoch 83/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 149.3722 - I_var: 0.3105 - val_loss: 149.4873 - val_I_var: 0.3010
# Epoch 84/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 149.6895 - I_var: 0.3076 - val_loss: 149.1144 - val_I_var: 0.3045
# Epoch 85/1000
# 92/92 [==============================] - 1s 5ms/step - loss: 151.8901 - I_var: 0.3083 - val_loss: 149.0228 - val_I_var: 0.3051
# Epoch 86/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 150.5367 - I_var: 0.3106 - val_loss: 148.6301 - val_I_var: 0.3088
# Epoch 87/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 149.6594 - I_var: 0.3127 - val_loss: 148.6399 - val_I_var: 0.3087
# Epoch 88/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 149.7206 - I_var: 0.3170 - val_loss: 148.7024 - val_I_var: 0.3086
# Epoch 89/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 147.5963 - I_var: 0.3173 - val_loss: 148.3833 - val_I_var: 0.3113
# Epoch 90/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 149.3028 - I_var: 0.3143 - val_loss: 148.6792 - val_I_var: 0.3099
# Epoch 91/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 148.5044 - I_var: 0.3086 - val_loss: 148.5114 - val_I_var: 0.3109
# Epoch 92/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 149.0987 - I_var: 0.3149 - val_loss: 148.2735 - val_I_var: 0.3129
# Epoch 93/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 149.2904 - I_var: 0.3187 - val_loss: 147.9034 - val_I_var: 0.3158
# Epoch 94/1000
# 92/92 [==============================] - 0s 5ms/step - loss: 150.1054 - I_var: 0.3202 - val_loss: 148.0134 - val_I_var: 0.3153
# Epoch 95/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 149.2845 - I_var: 0.3219 - val_loss: 148.0383 - val_I_var: 0.3147
# Epoch 96/1000
# 92/92 [==============================] - 1s 7ms/step - loss: 149.9217 - I_var: 0.3190 - val_loss: 147.8719 - val_I_var: 0.3165
# Epoch 97/1000
# 92/92 [==============================] - 1s 7ms/step - loss: 151.1293 - I_var: 0.3177 - val_loss: 148.0127 - val_I_var: 0.3156
# Epoch 98/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 149.6945 - I_var: 0.3201 - val_loss: 146.8606 - val_I_var: 0.3239
# Epoch 99/1000
# 92/92 [==============================] - 1s 6ms/step - loss: 147.6934 - I_var: 0.3193 - val_loss: 147.8223 - val_I_var: 0.3172
# Training time: 50.6 seconds

# %%
# Save model
model.save('mpsa_ge_pairwise')
# Out:
# Model saved to these files:
# 	mpsa_ge_pairwise.pickle
# 	mpsa_ge_pairwise.h5

# %%
# Load model
model = mavenn.load('mpsa_ge_pairwise')
# Out:
# Model loaded from these files:
# 	mpsa_ge_pairwise.pickle
# 	mpsa_ge_pairwise.h5

# %%
# Get x and y
x_test = test_df['x'].values
y_test = test_df['y'].values

# %%
# Show training history
print('On test data:')

# Compute likelihood information
I_var, dI_var =  model.I_variational(x=x_test, y=y_test)
print(f'I_var_test: {I_var:.3f} +- {dI_var:.3f} bits') 

# Compute predictive information
I_pred, dI_pred = model.I_predictive(x=x_test, y=y_test)
print(f'I_pred_test: {I_pred:.3f} +- {dI_pred:.3f} bits')

I_var_hist = model.history['I_var']
val_I_var_hist = model.history['val_I_var']

fig, ax = plt.subplots(1,1,figsize=[4,4])
ax.plot(I_var_hist, label='I_var_train')
ax.plot(val_I_var_hist, label='I_var_val')
ax.axhline(I_var, color='C2', linestyle=':', label='I_var_test')
ax.axhline(I_pred, color='C3', linestyle=':', label='I_pred_test')
ax.legend()
ax.set_xlabel('epochs')
ax.set_ylabel('bits')
ax.set_title('training hisotry')
ax.set_ylim([0, I_pred*1.2]);
# Out:
# On test data:
# I_var_test: 0.309 +- 0.023 bits
# I_pred_test: 0.381 +- 0.015 bits

# %%
# Predict latent phentoype values (phi) on test data
phi_test = model.x_to_phi(x_test)

# Predict measurement values (yhat) on test data
yhat_test = model.x_to_yhat(x_test)

# Set phi lims and create grid in phi space
phi_lim = [min(phi_test)-.5, max(phi_test)+.5]
phi_grid = np.linspace(phi_lim[0], phi_lim[1], 1000)

# Compute yhat each phi gridpoint
yhat_grid = model.phi_to_yhat(phi_grid)

# Compute 90% CI for each yhat
q = [0.05, 0.95] #[0.16, 0.84]
yqs_grid = model.yhat_to_yq(yhat_grid, q=q)

# Create figure
fig, ax = plt.subplots(1, 1, figsize=[4, 4])

# Illustrate measurement process with GE curve
ax.scatter(phi_test, y_test, color='C0', s=5, alpha=.2, label='test data')
ax.plot(phi_grid, yhat_grid, linewidth=2, color='C1',
        label='$\hat{y} = g(\phi)$')
ax.plot(phi_grid, yqs_grid[:, 0], linestyle='--', color='C1', label='68% CI')
ax.plot(phi_grid, yqs_grid[:, 1], linestyle='--', color='C1')
ax.set_xlim(phi_lim)
ax.set_xlabel('latent phenotype ($\phi$)')
ax.set_ylabel('measurement ($y$)')
ax.set_title('measurement process')
ax.legend()

# Fix up plot
fig.tight_layout()
plt.show()

# %%
# Plot pairwise parameters
theta = model.get_theta()
fig, ax = plt.subplots(1, 1, figsize=[8, 4])
mavenn.heatmap_pairwise(values=theta['theta_lclc'],
                        alphabet=theta['alphabet'],
                        ax=ax);

# %%
import logomaker
fig, ax = plt.subplots()
logo_df = model.get_theta()['logomaker_df'].fillna(0)
logo = logomaker.Logo(df=logo_df, ax=ax, fade_below=.5, shade_below=.5, width=.9, font_name='Arial Rounded MT Bold')


# Style logo
ylim = ax.get_ylim()
logo.highlight_position_range(pmin=3, pmax=4, color='w', alpha=1, zorder=10)
logo.highlight_position_range(pmin=3, pmax=4, color='gray', alpha=.1, zorder=11)
logo.style_single_glyph(p=3, c='G', floor=ylim[0], ceiling=ylim[1], color='gray', zorder=30, alpha=.5)
logo.style_single_glyph(p=4, c='U', color='k', zorder=30)
logo.style_single_glyph(p=4, c='C', color='k', zorder=30)
logo.style_spines(visible=False)

# Sytle axes
ax.axvline(2.5, linestyle=':', color='k', zorder=30)
ax.set_ylabel('additive effect ($\Delta \phi$)', labelpad=-1)
ax.set_xticks([0,1,2,3,4,5,6,7,8])
ax.set_xticklabels([f'{x:+d}' for x in range(-3,7) if x!=0])
ax.set_xlabel('nucleotide position', labelpad=5)
# Out:
# Text(0.5, 0, 'nucleotide position')
