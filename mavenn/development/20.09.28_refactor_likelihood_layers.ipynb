# %%
# Standard imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import time

# Insert path to mavenn beginning of path
import os
import sys
abs_path_to_mavenn = os.path.abspath('../../')
sys.path.insert(0, abs_path_to_mavenn)

# Load mavenn
import mavenn
print(mavenn.__path__)
# Out:
# ['/Users/jkinney/github/mavenn/mavenn']

# %%
# Load example data
data_df = mavenn.load_example_dataset(name='mpsa')
print(f'training N: {len(data_df)}')
data_df.head()
# Out:
# training N: 21929
#    training_set         y        dy          x
# 0         False -3.751854  0.444200  AAAGCAAAA
# 1          True -2.697741  0.369972  AAAGCAAAC
# 2          True -2.242947  0.575121  AAAGCAAAG
# 3         False -3.067251  0.357014  AAAGCAAAT
# 4         False -2.987074  0.472637  AAAGCAACA

# %%
ix = data_df['training_set']
train_df = data_df[ix].reset_index(drop=True)
test_df = data_df[~ix].reset_index(drop=True)
L = len(train_df['x'][0])
L
# Out:
# 9

# %%
y = train_df['y'].values
from mavenn.src.entropy import entropy_continuous
H_y = entropy_continuous(y, uncertainty=False)
print(f'H_y: {H_y} bits')
# Out:
# H_y: -0.912564494110383 bits

# %%
if True:

    # Set seeed
    mavenn.set_seed(0)

    # Define model
    model = mavenn.Model(L=len(train_df['x'][0]),
                         alphabet='dna',
                         gpmap_type='pairwise',
                         regression_type='GE',
                         ge_noise_model_type='Cauchy',
                         ge_heteroskedasticity_order=2)

    model.set_data(x=train_df['x'],
                   y=train_df['y'])

    # Fit model to data
    history = model.fit(learning_rate=.005,
                        batch_size=200,
                        epochs=1000,
                        early_stopping=True,
                        early_stopping_patience=50,
                        linear_initialization=True,
                        verbose=True)

    model.save('mpsa_ge_pairwise')
# Out:
# N = 17,498 observations set as training data.
# Data shuffled.
# Time to set data: 0.362 sec.
#
# LSMR            Least-squares solution of  Ax = b
#
# The matrix A has    17498 rows  and       36 cols
# damp = 0.00000000000000e+00
#
# atol = 1.00e-06                 conlim = 1.00e+08
#
# btol = 1.00e-06             maxiter =       36
#
#
#    itn      x(1)       norm r    norm Ar  compatible   LS      norm A   cond A
#      0  0.00000e+00  1.323e+02  4.299e+03   1.0e+00  2.5e-01
#      1  2.19200e-02  1.200e+02  1.397e+03   9.1e-01  1.5e-01  7.7e+01  1.0e+00
#      2  2.59784e-02  1.186e+02  7.118e+02   9.0e-01  5.2e-02  1.1e+02  1.1e+00
#      3  2.96533e-02  1.184e+02  2.279e+02   9.0e-01  7.5e-03  2.6e+02  2.4e+00
#      4  3.10860e-02  1.183e+02  5.410e+01   8.9e-01  1.7e-03  2.7e+02  3.1e+00
#      5  3.20917e-02  1.183e+02  1.251e+01   8.9e-01  3.7e-04  2.8e+02  3.4e+00
#      6  3.22692e-02  1.183e+02  1.248e+00   8.9e-01  3.7e-05  2.9e+02  3.5e+00
#      7  3.22536e-02  1.183e+02  2.542e-01   8.9e-01  7.2e-06  3.0e+02  3.5e+00
#      8  3.22424e-02  1.183e+02  6.790e-02   8.9e-01  1.9e-06  3.0e+02  3.5e+00
#      9  3.22416e-02  1.183e+02  1.024e-02   8.9e-01  2.8e-07  3.1e+02  3.5e+00
#
# LSMR finished
# The least-squares solution is good enough, given atol
# istop =       2    normr = 1.2e+02
#     normA = 3.1e+02    normAr = 1.0e-02
# itn   =       9    condA = 3.5e+00
#     normx = 8.5e-01
#      9  3.22416e-02   1.183e+02  1.024e-02
#    8.9e-01  2.8e-07   3.1e+02  3.5e+00
# Linear regression time: 0.0275 sec
# Epoch 1/1000
# 70/70 [==============================] - 0s 7ms/step - loss: 276.4655 - I_like: -0.7099 - val_loss: 240.6795 - val_I_like: -0.4805
# Epoch 2/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 229.7668 - I_like: -0.3837 - val_loss: 208.9994 - val_I_like: -0.2554
# Epoch 3/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 205.6404 - I_like: -0.2133 - val_loss: 195.8073 - val_I_like: -0.1595
# Epoch 4/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 193.3271 - I_like: -0.1249 - val_loss: 185.1521 - val_I_like: -0.0826
# Epoch 5/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 184.0119 - I_like: -0.0559 - val_loss: 177.1062 - val_I_like: -0.0239
# Epoch 6/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 176.1482 - I_like: 0.0040 - val_loss: 172.4594 - val_I_like: 0.0127
# Epoch 7/1000
# 70/70 [==============================] - 0s 4ms/step - loss: 173.4306 - I_like: 0.0253 - val_loss: 171.2115 - val_I_like: 0.0222
# Epoch 8/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 172.2707 - I_like: 0.0351 - val_loss: 174.4814 - val_I_like: -0.0011
# Epoch 9/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 169.5606 - I_like: 0.0564 - val_loss: 171.8059 - val_I_like: 0.0198
# Epoch 10/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 167.7755 - I_like: 0.0714 - val_loss: 167.5087 - val_I_like: 0.0537
# Epoch 11/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 160.2051 - I_like: 0.1288 - val_loss: 159.6680 - val_I_like: 0.1121
# Epoch 12/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 157.6319 - I_like: 0.1473 - val_loss: 159.6306 - val_I_like: 0.1131
# Epoch 13/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 153.9150 - I_like: 0.1737 - val_loss: 156.5614 - val_I_like: 0.1362
# Epoch 14/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 153.7419 - I_like: 0.1749 - val_loss: 157.6809 - val_I_like: 0.1296
# Epoch 15/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 154.4251 - I_like: 0.1700 - val_loss: 156.2755 - val_I_like: 0.1381
# Epoch 16/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 153.3408 - I_like: 0.1775 - val_loss: 156.1438 - val_I_like: 0.1392
# Epoch 17/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 154.4239 - I_like: 0.1701 - val_loss: 158.4358 - val_I_like: 0.1237
# Epoch 18/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 153.1436 - I_like: 0.1796 - val_loss: 155.9987 - val_I_like: 0.1400
# Epoch 19/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 152.5817 - I_like: 0.1837 - val_loss: 158.1551 - val_I_like: 0.1271
# Epoch 20/1000
# Epoch 62/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 150.1153 - I_like: 0.2036 - val_loss: 162.4404 - val_I_like: 0.0989
# Epoch 63/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 151.0387 - I_like: 0.1968 - val_loss: 156.2481 - val_I_like: 0.1417
# Epoch 64/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 150.4037 - I_like: 0.2014 - val_loss: 157.3746 - val_I_like: 0.1336
# Epoch 65/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 150.6710 - I_like: 0.1994 - val_loss: 155.9726 - val_I_like: 0.1422
# Epoch 66/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 151.7635 - I_like: 0.1912 - val_loss: 158.2522 - val_I_like: 0.1280
# Epoch 67/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 150.5651 - I_like: 0.1999 - val_loss: 157.5468 - val_I_like: 0.1333
# Epoch 68/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 150.8109 - I_like: 0.1981 - val_loss: 155.1819 - val_I_like: 0.1493
# Epoch 69/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 151.3576 - I_like: 0.1942 - val_loss: 156.6149 - val_I_like: 0.1398
# Epoch 70/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 150.7297 - I_like: 0.1987 - val_loss: 155.7930 - val_I_like: 0.1450
# Epoch 71/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 150.7985 - I_like: 0.1984 - val_loss: 163.7107 - val_I_like: 0.0895
# Epoch 72/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 150.9486 - I_like: 0.1973 - val_loss: 156.7663 - val_I_like: 0.1404
# Epoch 73/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 150.3300 - I_like: 0.2016 - val_loss: 156.8499 - val_I_like: 0.1378
# Epoch 74/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 151.6000 - I_like: 0.1924 - val_loss: 157.4321 - val_I_like: 0.1343
# Epoch 75/1000
# 70/70 [==============================] - 0s 3ms/step - loss: 149.4397 - I_like: 0.2085 - val_loss: 158.0980 - val_I_like: 0.1301
# Training time: 18.0 seconds
# Model saved to these files:
# 	mpsa_ge_pairwise.pickle
# 	mpsa_ge_pairwise.h5

# %%
model = mavenn.load('mpsa_ge_pairwise')
# Out:
# Model loaded from these files:
# 	mpsa_ge_pairwise.pickle
# 	mpsa_ge_pairwise.h5

# %%
x = test_df['x'].values
y = test_df['y'].values
dy = test_df['dy'].values

print('On test data:')

# Compute intrinsic information
I_intr, dI_intr = mavenn.I_intrinsic(y_values=y, dy_values=dy)
print(f'I_intr: {I_intr:.3f} +- {dI_intr:.3f} bits')

# Compute predictive information
I_pred, dI_pred = model.I_predictive(x=x, y=y)
print(f'I_pred: {I_pred:.3f} +- {dI_pred:.3f} bits')

# Compute likelihood information
I_like, dI_like =  model.I_likelihood(x=x, y=y)
print(f'I_like: {I_like:.3f} +- {dI_like:.3f} bits') 

I_like_hist = model.history['I_like']
val_I_like_hist = model.history['val_I_like']

fig, ax = plt.subplots(1,1,figsize=[4,4])
ax.plot(I_like_hist, label='I_like_hist')
ax.plot(val_I_like_hist, label='val_I_like_hist')
#ax.set_ylim([0,1])
ax.axhline(I_pred, color='C0', linestyle=':', label='I_pred')
ax.axhline(I_like, color='C2', linestyle=':', label='I_like')
ax.axhline(I_intr, color='C3', linestyle=':', label='I_int')
ax.legend()
ax.set_xlabel('epochs')
ax.set_ylabel('bits')
# Out:
# On test data:
# I_intr: 0.785 +- 0.024 bits
# I_pred: 0.372 +- 0.016 bits
# I_like: 0.184 +- 0.027 bits
# Text(0, 0.5, 'bits')

# %%
# Get x and y
x_test = test_df['x'].values
y_test = test_df['y'].values

# %%
# Predict latent phentoype values (phi) on test data
phi_test = model.x_to_phi(x_test)

# Predict measurement values (yhat) on test data
yhat_test = model.x_to_yhat(x_test)

# Set phi lims and create grid in phi space
phi_lim = [min(phi_test)-.5, max(phi_test)+.5]
phi_grid = np.linspace(phi_lim[0], phi_lim[1], 1000)

# Compute yhat each phi gridpoint
yhat_grid = model.phi_to_yhat(phi_grid)

# Compute 68% CI for each yhat
yqs_grid = model.yhat_to_yq(yhat_grid, q=[0.16, 0.84])

# Create figure
fig, axs = plt.subplots(1, 2, figsize=[12, 5])

# Illustrate measurement process with GE curve
ax = axs[0]
ax.scatter(phi_test, y_test, color='C0', s=5, alpha=.2, label='test data')
ax.plot(phi_grid, yhat_grid, linewidth=2, color='C1',
        label='$\hat{y} = g(\phi)$')
ax.plot(phi_grid, yqs_grid[:, 0], linestyle='--', color='C1', label='68% CI')
ax.plot(phi_grid, yqs_grid[:, 1], linestyle='--', color='C1')
ax.set_xlim(phi_lim)
y_lim = [-6,3]
ax.set_ylim(y_lim)
ax.set_xlabel('latent phenotype ($\phi$)')
ax.set_ylabel('measurement ($y$)')
ax.set_title('measurement process')
ax.legend()

# Create grids
y_grid = np.linspace(y_lim[0], y_lim[1], 200)
phi_grid = np.linspace(phi_lim[0], phi_lim[1], 100)
yhat_grid = model.phi_to_yhat(phi_grid)

ax = axs[1]
p_y_given_phi = model.p_of_y_given_phi(y_grid, phi_grid, paired=False)
clim = np.quantile(p_y_given_phi.ravel(), q=[0.01, 0.99])
extent = phi_lim + y_lim
im = ax.imshow(p_y_given_phi, 
          extent=extent, 
          interpolation='nearest', 
          origin='lower', 
          vmin=clim[0], 
          vmax=clim[1])
#plt.colorbar(im)
ax.set_title('p(y|phi)')
ax.set_xlabel('phi')
ax.set_ylabel('y')

# Fix up plot
#fig.tight_layout()

plt.show()

# %%
# Plot pairwise parameters
theta_dict = model.get_theta(gauge='uniform')
fig, ax = plt.subplots(1, 1, figsize=[8, 4])
mavenn.heatmap_pairwise(theta_dict['theta_lclc'],
                        alphabet=theta_dict['alphabet'],
                        ax=ax);

# %%
# Create synthetic data
N = 10000
sim_df = model.simulate_dataset(N)
sim_df.head()
# Out:
#    training_set      yhat       phi         y          x
# 0          True -2.828274  1.224983 -2.656576  GGGGTCTGT
# 1          True -3.092912  0.728442 -3.144699  ATGGTCCGA
# 2          True -3.150906 -0.240563 -2.747064  AGCGCCCAT
# 3          True -3.140196  0.034966 -3.527645  TGTGCTCAA
# 4          True -3.073012  0.836191 -3.399939  ATTGTGAAA

# %%
from varname import nameof
nameof(model)
# Out:
# 'model'
