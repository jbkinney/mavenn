# %%
# Standard imports
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Add mavenn to path
import sys
path_to_mavenn_local = '../../'
sys.path.insert(0,path_to_mavenn_local)

# Load mavenn and check path
import mavenn
mavenn.__path__
# Out:
# ['../../mavenn']

# %%
# Load model
model = mavenn.load_example(which="model", name="mpsa_ge_pairwise")
# Out:
# Model loaded from these files:
# 	../../mavenn/examples/models/mpsa_ge_pairwise.pickle
# 	../../mavenn/examples/models/mpsa_ge_pairwise.h5

# %%
theta = model.get_theta()
theta.keys()
# Out:
# dict_keys(['L', 'C', 'alphabet', 'theta_0', 'theta_lc', 'theta_lclc'])

# %%
mavenn.heatmap(values=theta['theta_lc'], 
               alphabet=theta['alphabet'],
               ccenter=0);

# %%
mavenn.heatmap_pairwise(values=theta['theta_lclc'], 
                        alphabet=theta['alphabet'], 
                        gpmap_type='pairwise',
                        ccenter=0);
