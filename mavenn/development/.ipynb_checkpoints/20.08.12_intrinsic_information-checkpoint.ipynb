# %%
import numpy as np
import pandas as pd
from scipy.integrate import quad
import matplotlib.pyplot as plt
import suftware as su

# %% [markdown]
# Here we estimate the intrinsic information in the psi_9nt dataset.

# %%
df = pd.read_csv('psi_9nt.csv')
df.head()
# Out:
#          seq  brca2_9nt  brca2_9nt_stderr  ikbkap_9nt  ikbkap_9nt_stderr  \
# 0  AAAGCAAAA   0.373522          0.095217    0.080039           0.081333
# 1  AAAGCAAAC   0.688386          0.063575    0.061021           0.018316
# 2  AAAGCAAAG   0.756357          0.481555    0.045032           0.023374
# 3  AAAGCAAAU   0.443014          0.127961    0.071423           0.028762
# 4  AAAGCAACA   0.548363          0.140963    0.100128           0.071551
#
#    smn1_9nt  smn1_9nt_stderr
# 0  0.227001         0.082164
# 1  0.522138         0.017503
# 2  0.210907         0.170688
# 3  0.232645         0.044371
# 4  0.362139         0.127696

# %%
y_col = 'brca2_9nt'
dy_col = 'brca2_9nt_stderr'
df = df[[y_col, dy_col]].dropna()
psi = df[y_col].values
dpsi = df[dy_col].values
ix = (psi > 0) & (dpsi > 0)
psi = psi[ix]
dpsi = dpsi[ix]
y = np.log(psi)
dy = dpsi/psi
plt.semilogy(y,dy,'.',alpha=.1)

# %%
# Compute noisy y 
y_noise = y + np.random.normal(loc=0,scale=dy)

# %%
# Use DEFT to compute entropy
p = su.DensityEstimator(y, num_grid_points=200)
#p = su.DensityEstimator(y_noise, num_grid_points=200)  # DON'T USE THIS!
stats_df = p.get_stats()
H_y = -stats_df.loc['posterior mean','entropy']
dH_y = stats_df.loc['posterior RMSD','entropy']
print(f'From DEFT: H[y] = {H_y:.4f} +- {dH_y:.4f} bits')
p.plot() # Check by eye that distribution makes sense
stats_df # Entroy has the wrong sign!
# Out:
# From DEFT: H[y] = 1.2220 +- 0.0097 bits
#                    entropy        mean   variance    skewness  kurtosis
# star               -1.2225    -0.40116    1.27686     2.95894   12.6201
# histogram         -1.20849   -0.401312    1.27603     2.95913   12.6197
# maxent            -2.22294   -0.401308    1.27606  0.00011623    2.9995
# posterior mean    -1.22197   -0.400823    1.27726     2.96123   12.6298
# posterior RMSD  0.00969103  0.00611724  0.0227071   0.0255496  0.216673

# %%
# Double-check that this is right
x_min = p.bounding_box[0]
x_max = p.bounding_box[1]
G = 1000
x_grid = np.linspace(x_min, x_max, G)
dx = x_grid[1]-x_grid[0]
p_grid = p.density_func(x_grid)
H_y_check = -np.sum(dx*p_grid * np.log2(p_grid))
print(f'From manual calculation, H[y] = {H_y_check:.4f}')
# Out:
# From manual calculation, H[y] = 1.2225

# %% [markdown]
# For a Gaussian distribution with variance $\sigma^2$:
#
# $$ H = \frac{1}{2} \log_2(2 \pi e \sigma^2) ~~~ \Leftrightarrow ~~~ \sigma = \frac{2^H}{\sqrt{2 \pi e}} $$

# %%
# Compute the sequence-conditioned entropy
e = np.exp(1)
pi = np.pi
Hs_bits = .5*np.log2(2*pi*e*dy**2)
N = len(Hs_bits)
H_ygx = np.mean(Hs_bits)
dH_ygx = np.std(Hs_bits)/np.sqrt(N)
print(f'H[y|x] = {H_ygx:.4f} +- {dH_ygx:.4f} bits')
# Out:
# H[y|x] = -0.4608 +- 0.0099 bits

# %%
# Compute the effective dy from this entropy
dy_eff = (2**H_ygx)/np.sqrt(2*pi*e)
print(f'Effective dy is = {dy_eff:.4f}')
H_eff = 0.5*np.log2(2*pi*e*dy_eff**2)
print(f'If all points had this dy value, entropy would be {H_eff:.4f}.')
plt.semilogy(y,dy,'.',alpha=.1)
plt.axhline(dy_eff, color='k', linestyle=':')
# Out:
# Effective dy is = 0.1758
# If all points had this dy value, entropy would be -0.4608.

# %%
# Finally, compute intrinsic information in experiment
I_y_x = H_y - H_ygx
dI_y_x = np.sqrt(dH_y**2 + dH_ygx**2)
print(f'I[y;x] = {I_y_x:.4f} +- {dI_y_x:.4f} bits')
# Out:
# I[y;x] = 1.6828 +- 0.0138 bits

# %%
# Load data
df = pd.read_csv('psi_9nt.csv')

# Get useful consts
e = np.exp(1)
pi = np.pi

for locus in ['brca2','smn1','ikbkap']:

    # Provide feedback
    print(f'\n{locus}:')
    
    # Extract psi values from dataframe
    y_col = f'{locus}_9nt'
    dy_col = f'{locus}_9nt_stderr'
    tmp_df = df[[y_col, dy_col]].copy().dropna()
    psi = tmp_df[y_col].values
    dpsi = tmp_df[dy_col].values
    ix = (psi > 0) & (dpsi > 0)
    psi = psi[ix]
    dpsi = dpsi[ix]
    
    # Compute y and dy values to do the estimation on
    y = np.log(psi)
    dy = dpsi/psi

    # Use DEFT to compute H[y]
    p = su.DensityEstimator(y, num_grid_points=200)
    stats_df = p.get_stats()
    H_y = -stats_df.loc['posterior mean','entropy']
    dH_y = stats_df.loc['posterior RMSD','entropy']
    print(f'H[y]   = {H_y:.4f} +- {dH_y:.4f} bits')
    
    # Use the formula for Gaussian entropy to compute H[y|x]
    Hs_bits = .5*np.log2(2*pi*e*dy**2)
    N = len(Hs_bits)
    H_ygx = np.mean(Hs_bits)
    dH_ygx = np.std(Hs_bits)/np.sqrt(N)
    print(f'H[y|x] = {H_ygx:.4f} +- {dH_ygx:.4f} bits')
    
    # Finally, compute intrinsic information in experiment
    I_y_x = H_y - H_ygx
    dI_y_x = np.sqrt(dH_y**2 + dH_ygx**2)
    print(f'I[y;x] = {I_y_x:.4f} +- {dI_y_x:.4f} bits')
# Out:
# brca2:
# H[y] = 1.2205 +- 0.0095 bits
# H[y|x] = -0.4608 +- 0.0099 bits
# I[y;x] = 1.6814 +- 0.0137 bits
#
# smn1:
# H[y] = 2.6870 +- 0.0055 bits
# H[y|x] = 0.3159 +- 0.0092 bits
# I[y;x] = 2.3711 +- 0.0107 bits
#
# ikbkap:
# H[y] = 1.6462 +- 0.0094 bits
# H[y|x] = 1.1318 +- 0.0112 bits
# I[y;x] = 0.5144 +- 0.0146 bits
